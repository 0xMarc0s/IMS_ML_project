# %% [markdown]
# # GOAL:
# - Experiment to determine methods of imputation
# - Idea: Try different ways of imputation, use the baseline model (decision trees or random forests) and evaluate. Select best model.
#
# Approach: Make the pipeline as much as efficient as possible, by using *"configurations"* for imputing values (exm: impute variable $X$ in a manner $f$)

# %%
import pandas as pd
import sklearn as sk

# %%
df = pd.read_csv(r"../our data/no_outliers.csv")
df.head(3)
# Out:
#    Unnamed: 0   age alcohol_freq caloric_freq devices_perday  \
# 0           0  21.0        Never           no        up to 5
# 1           1  23.0   Frequently           no        up to 5
# 2           2   NaN   Frequently           no        up to 2
#
#   eat_between_meals  gender  height  meals_perday monitor_calories  \
# 0         Sometimes  Female    1.62           3.0               no
# 1         Sometimes    Male    1.80           3.0               no
# 2         Sometimes    Male    1.80           3.0               no
#
#   parent_overweight physical_activity_perweek  siblings smoke transportation  \
# 0               yes                       NaN       3.0    no         Public
# 1               yes                    3 to 4       0.0    no         Public
# 2                no                    3 to 4       2.0    no           Walk
#
#   veggies_freq water_daily  weight         obese_level
# 0    Sometimes      1 to 2    64.0       Normal_Weight
# 1    Sometimes      1 to 2    77.0       Normal_Weight
# 2       Always      1 to 2    87.0  Overweight_Level_I

# %%
df = df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ## Separate explanatory and targets

# %%
df_var, df_target = df.drop("obese_level", axis=1), df['obese_level']

# %% [markdown]
# # Separate train and validation

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df_var, df_target,
    test_size = .33,
    random_state=20
)

# %%
df.dtypes
# Out:
# age                          float64
# alcohol_freq                  object
# caloric_freq                  object
# devices_perday                object
# eat_between_meals             object
# gender                        object
# height                       float64
# meals_perday                 float64
# monitor_calories              object
# parent_overweight             object
# physical_activity_perweek     object
# siblings                     float64
# smoke                         object
# transportation                object
# veggies_freq                  object
# water_daily                   object
# weight                       float64
# obese_level                   object
# dtype: object

# %% [markdown]
# # Start experimenting
# ## Setup configurations and results

# %%
from sklearn.experimental import enable_iterative_imputer

from data_preprocesser import preprocesser

# %%
my_preprocesser = preprocesser()

# Data preprocesser:
def run(o_train, o_val, configs):
    # Preserve original data as preprocesser does everything inplace
    train = o_train.copy()
    val = o_val.copy()

    for config in configs:
        l = config.split(";")

        if len(l) == 1: # Single-argument options only
            option = l[0]            
            if option == "knn_imputer":
                train, val = my_preprocesser.knn_imputer(train, val, configs[config])
            
            if option == "add_bmi":
                train, val = my_preprocesser.add_bmi(train, val)
            
        if len(l) == 2: # Two options
            option = l[0]
            arg = l[1]

            if option == "encode_data":
                train, val = my_preprocesser.encode_data(train, val, configs[config], type=arg)

            if option == "simp_imputer":
                train, val = my_preprocesser.simp_imputer(train, val, configs[config], strategy=arg)
            
            if option == "scaler":
                train, val = my_preprocesser.scaler(train, val, configs[config], method=arg)
            
            if option == "constant_imputer":
                train, val = my_preprocesser.constant_imputer(train, val, configs[config], filling=arg)

            if option == "iterative_imputer":
                train, val = my_preprocesser.iterative_imputer(train, val, configs[config], estimator=arg)
        
    return train, val
# Out:
# Preprocesser loaded

# %% [markdown]
# # Start making some configurations

# %%
configs = []

# %%
config_6 = {
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "iterative_imputer;lr": ['age', 'weight', 'height'],
    "simp_imputer;most_frequent": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            ],
    "constant_imputer;0": [
                            'physical_activity_perweek'
                            ],
    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # 4 but added bmi
configs.append(config_6)

# %%
config_7 = {
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "iterative_imputer;lr": ['age', 'weight', 'height'],
    "knn_imputer":[
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            ],
    "constant_imputer;0": [
                            'physical_activity_perweek'
                            ],

} # previous but i'm using knn
configs.append(config_7)

# %%
config_8 = {
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "knn_imputer": ['age', 'weight', 'height'],
    "simp_imputer;most_frequent": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            ],
    "constant_imputer;0": [
                            'physical_activity_perweek'
                            ],
    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # 6 but using knn instead of lr
configs.append(config_8)

# %%
config_9 = {
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "knn_imputer": ['age', 'weight', 'height'],
    "simp_imputer;most_frequent": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            'physical_activity_perweek'
                            ],
    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # before but imputing physical activity with mode

# IMPORTANT OBSERVATION: In some categories performance slightly improves with this
configs.append(config_9)

# %%
config_10 = {
    "knn_imputer": ['age', 'weight', 'height'],
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],

    "simp_imputer;most_frequent": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            'physical_activity_perweek'
                            ],
    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # mix orders; KNN first and BMI later (+0.01 better performance)

configs.append(config_10)

# %%
config_11 = {
    "knn_imputer": ['age', 'weight', 'height'],
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],

    "iterative_imputer;KNNclassifier": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            'physical_activity_perweek'
                            ],
    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # fill categorical with iterative KNN

configs.append(config_11)

# %%
config_12 = {
    "knn_imputer": ['age', 'weight', 'height'],
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "constant_imputer;None": [
                            'physical_activity_perweek'
                            ],

    "iterative_imputer;KNNclassifier": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            ],

    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals"
    ],
"encode_data;one_hot": [
        "gender",
        "smoke",
    ]
} # same as before but constant imputer for physical activity

configs.append(config_12)

# %%
config_13 = {
    "knn_imputer": ['age', 'weight', 'height'],
    "add_bmi": None,
    "scaler;standard": ['age', 'weight', 'height'],
    "constant_imputer;None": [
                            'physical_activity_perweek'
                            ],

    "encode_data;ordinal": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'physical_activity_perweek',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            "bmi_class",
                            "eat_between_meals",
                            "gender",
                            "smoke",
                             ]
,
    "iterative_imputer;KNNclassifier": [
                            'alcohol_freq',
                            'caloric_freq',
                            'devices_perday',
                            'eat_between_meals',
                            'gender',
                            'meals_perday',
                            'monitor_calories',
                            'parent_overweight',
                            'smoke',
                            'transportation',
                            'veggies_freq',
                            'water_daily',
                            ],
} # previous but reversed order
configs.append(config_13)

# %% [markdown]
# # Mass Experiments with Baseline Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

trees = []
class_weights = {
    'Insufficient_Weight': 1.0,
    'Normal_Weight': 5,
    'Overweight_Level_I': 5,
    'Overweight_Level_II': 1.0,
    'Obesity_Type_I': 1.0,
    'Obesity_Type_II': 1.0,
    'Obesity_Type_III': 1.0
}
# For loop with configurations
for i,config in enumerate(configs):
    # Creates a random forest classifier, trains on preprocessed data with a certain configuration and evaluates
    tree_rf = RandomForestClassifier(random_state=42)
    print("="*50)
    print(f"CONFIGURATION {i+6}")
    print([e for e in config])
    print()
    train_curr, test_curr = run(X_train, X_test, config)
    tree_rf.fit(train_curr, y_train)

    print(classification_report(y_test, tree_rf.predict(test_curr)))
    
    trees.append(tree_rf)

#   importances = tree_rf.feature_importances_
#   importances_df = pd.DataFrame(importances, index=train_curr.columns, columns=['importance'])
#   importances_df = importances_df.sort_values('importance', ascending=False)
#   print(importances_df)
#   print()
# Out:
# ==================================================
# CONFIGURATION 6
# ['add_bmi', 'scaler;standard', 'iterative_imputer;lr', 'simp_imputer;most_frequent', 'constant_imputer;0', 'encode_data;ordinal', 'encode_data;one_hot']
#
# ['age', 'weight', 'height']
# ['age', 'alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'height', 'meals_perday', 'monitor_calories', 'parent_overweight', 'physical_activity_perweek', 'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily', 'weight', 'bmi_class']
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       1.00      0.89      0.94        75
#       Normal_Weight       0.71      0.93      0.81        70
#      Obesity_Type_I       0.94      0.94      0.94        80
#     Obesity_Type_II       0.97      0.96      0.97        76
#    Obesity_Type_III       0.99      1.00      0.99        75
#  Overweight_Level_I       0.93      0.81      0.86        79
# Overweight_Level_II       0.93      0.89      0.91        75
#
#            accuracy                           0.92       530
#           macro avg       0.92      0.92      0.92       530
#        weighted avg       0.93      0.92      0.92       530
#
# ==================================================
# CONFIGURATION 7
# ['add_bmi', 'scaler;standard', 'iterative_imputer;lr', 'knn_imputer', 'constant_imputer;0']
#
# ['age', 'weight', 'height']
# ['age', 'alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'height', 'meals_perday', 'monitor_calories', 'parent_overweight', 'physical_activity_perweek', 'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily', 'weight', 'bmi_class']
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.97      0.89      0.93        75
#       Normal_Weight       0.81      0.89      0.84        70
#      Obesity_Type_I       0.89      0.93      0.91        80
#     Obesity_Type_II       0.97      0.95      0.96        76
#    Obesity_Type_III       0.99      0.97      0.98        75
#  Overweight_Level_I       0.91      0.86      0.88        79
# Overweight_Level_II       0.92      0.96      0.94        75
#
#            accuracy                           0.92       530
#           macro avg       0.92      0.92      0.92       530
#        weighted avg       0.92      0.92      0.92       530
#
# ==================================================
# CONFIGURATION 8
# ['add_bmi', 'scaler;standard', 'knn_imputer', 'simp_imputer;most_frequent', 'constant_imputer;0', 'encode_data;ordinal', 'encode_data;one_hot']
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.96      0.92      0.94        75
#       Normal_Weight       0.85      0.89      0.87        70
#      Obesity_Type_I       0.93      0.95      0.94        80
#     Obesity_Type_II       0.99      0.96      0.97        76
#    Obesity_Type_III       0.99      1.00      0.99        75
#  Overweight_Level_I       0.89      0.84      0.86        79
# Overweight_Level_II       0.90      0.95      0.92        75
#
#            accuracy                           0.93       530
#           macro avg       0.93      0.93      0.93       530
#        weighted avg       0.93      0.93      0.93       530
#
# ==================================================
# CONFIGURATION 9
# ['add_bmi', 'scaler;standard', 'knn_imputer', 'simp_imputer;most_frequent', 'encode_data;ordinal', 'encode_data;one_hot']
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.96      0.92      0.94        75
#       Normal_Weight       0.85      0.91      0.88        70
#      Obesity_Type_I       0.91      0.96      0.93        80
#     Obesity_Type_II       0.99      0.95      0.97        76
#    Obesity_Type_III       0.99      1.00      0.99        75
#  Overweight_Level_I       0.88      0.87      0.88        79
# Overweight_Level_II       0.96      0.91      0.93        75
#
#            accuracy                           0.93       530
#           macro avg       0.93      0.93      0.93       530
#        weighted avg       0.93      0.93      0.93       530
#
# ==================================================
# CONFIGURATION 10
# ['knn_imputer', 'add_bmi', 'scaler;standard', 'simp_imputer;most_frequent', 'encode_data;ordinal', 'encode_data;one_hot']
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.99      0.91      0.94        75
#       Normal_Weight       0.84      0.93      0.88        70
#      Obesity_Type_I       0.94      0.97      0.96        80
#     Obesity_Type_II       0.99      0.97      0.98        76
#    Obesity_Type_III       0.99      1.00      0.99        75
#  Overweight_Level_I       0.91      0.89      0.90        79
# Overweight_Level_II       0.95      0.92      0.93        75
#
#            accuracy                           0.94       530
#           macro avg       0.94      0.94      0.94       530
#        weighted avg       0.94      0.94      0.94       530
#
# ==================================================
# CONFIGURATION 11
# ['knn_imputer', 'add_bmi', 'scaler;standard', 'iterative_imputer;KNNclassifier', 'encode_data;ordinal', 'encode_data;one_hot']
#
# ['alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'meals_perday', 'monitor_calories', 'parent_overweight', 'smoke', 'transportation', 'veggies_freq', 'water_daily', 'physical_activity_perweek']
# ['age', 'alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'height', 'meals_perday', 'monitor_calories', 'parent_overweight', 'physical_activity_perweek', 'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily', 'weight', 'bmi_class']
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       1.00      0.91      0.95        75
#       Normal_Weight       0.86      0.93      0.89        70
#      Obesity_Type_I       0.92      0.97      0.95        80
#     Obesity_Type_II       0.99      0.96      0.97        76
#    Obesity_Type_III       1.00      1.00      1.00        75
#  Overweight_Level_I       0.92      0.89      0.90        79
# Overweight_Level_II       0.95      0.96      0.95        75
#
#            accuracy                           0.95       530
#           macro avg       0.95      0.95      0.95       530
#        weighted avg       0.95      0.95      0.95       530
#
# ==================================================
# CONFIGURATION 12
# ['knn_imputer', 'add_bmi', 'scaler;standard', 'constant_imputer;None', 'iterative_imputer;KNNclassifier', 'encode_data;ordinal', 'encode_data;one_hot']
#
# ['alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'meals_perday', 'monitor_calories', 'parent_overweight', 'smoke', 'transportation', 'veggies_freq', 'water_daily']
# ['age', 'alcohol_freq', 'caloric_freq', 'devices_perday', 'eat_between_meals', 'gender', 'height', 'meals_perday', 'monitor_calories', 'parent_overweight', 'physical_activity_perweek', 'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily', 'weight', 'bmi_class']
# c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.99      0.92      0.95        75
#       Normal_Weight       0.84      0.91      0.88        70
#      Obesity_Type_I       0.92      0.97      0.95        80
#     Obesity_Type_II       0.99      0.96      0.97        76
#    Obesity_Type_III       0.99      1.00      0.99        75
#  Overweight_Level_I       0.93      0.87      0.90        79
# Overweight_Level_II       0.93      0.93      0.93        75
#
#            accuracy                           0.94       530
#           macro avg       0.94      0.94      0.94       530
#        weighted avg       0.94      0.94      0.94       530
#
# ==================================================
# CONFIGURATION 13
# ['knn_imputer', 'add_bmi', 'scaler;standard', 'constant_imputer;None', 'encode_data;ordinal']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 22
#      20 print([e for e in config])
#      21 print()
# ---> 22 train_curr, test_curr = run(X_train, X_test, config)
#      23 tree_rf.fit(train_curr, y_train)
#      25 print(classification_report(y_test, tree_rf.predict(test_curr)))
#
# Cell In[8], line 25, in run(o_train, o_val, configs)
#      22 arg = l[1]
#      24 if option == "encode_data":
# ---> 25     train, val = my_preprocesser.encode_data(train, val, configs[config], type=arg)
#      27 if option == "simp_imputer":
#      28     train, val = my_preprocesser.simp_imputer(train, val, configs[config], strategy=arg)
#
# File c:\Users\ACER\Desktop\IMS_ML_project\Preliminary Notebooks\data_preprocesser.py:158, in preprocesser.encode_data(self, data_train, data_test, columns, type)
#     155 encoded_train[f"{target}"] = transformed_train
#     157 # Transform test data
# --> 158 transformed_test = target_encoder.transform(encoded_test[[target]])
#     159 encoded_test[f"{target}"] = transformed_test
#     161 # Drop original columns
#     162 # encoded_train.drop(columns=[target], inplace=True)
#     163 # encoded_test.drop(columns=[target], inplace=True)
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1578, in OrdinalEncoder.transform(self, X)
#    1564 """
#    1565 Transform X to ordinal codes.
#    1566
#    (...)
#    1575     Transformed input.
#    1576 """
#    1577 check_is_fitted(self, "categories_")
# -> 1578 X_int, X_mask = self._transform(
#    1579     X,
#    1580     handle_unknown=self.handle_unknown,
#    1581     force_all_finite="allow-nan",
#    1582     ignore_category_indices=self._missing_indices,
#    1583 )
#    1584 X_trans = X_int.astype(self.dtype, copy=False)
#    1586 for cat_idx, missing_idx in self._missing_indices.items():
#
# File c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:214, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     209 if handle_unknown == "error":
#     210     msg = (
#     211         "Found unknown categories {0} in column {1}"
#     212         " during transform".format(diff, i)
#     213     )
# --> 214     raise ValueError(msg)
#     215 else:
#     216     if warn_on_unknown:
#
# ValueError: Found unknown categories ['2.2'] in column 0 during transform

# %% [markdown]
# # Conclusions
# The best configurations is $12$, where we:
# - Impute age, weight, height with KNN
# - Add BMI class
# - Scale age, weight, height with standard scaling
# - Impute physical activity with "None" (NaN is interpreted as No activity)
# - Impute qualitative variabiles either with mode or KNN classifier (the performance does not significantly change)
# - Encode qualitative data
#
# This yields us an average f1-score of $0.95$ on validation set.
#
# **NOTE:** While this configuration has the best global f1-score, it is to note that we have some tradeoffs; in particular, it performs worse on predicting `Normal Weight` and `Overweight Level II`

# %%
importances = trees[12].feature_importances_
importances_df = pd.DataFrame(importances, index=train_curr.columns, columns=['importance'])
importances_df = importances_df.sort_values('importance', ascending=False)
print(importances_df) # Importances of last model
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 importances = trees[12].feature_importances_
#       2 importances_df = pd.DataFrame(importances, index=train_curr.columns, columns=['importance'])
#       3 importances_df = importances_df.sort_values('importance', ascending=False)
#
# IndexError: list index out of range

# %% [markdown]
# Trying to predict my own obesity

# %%
my_data = {
    "age": 20.0,
    "alcohol_freq": "Always",
    "caloric_freq": "no",
    "devices_perday": "more than 5",
    "eat_between_meals": "Sometimes",
    "gender": "Male",
    "height": 1.72,
    "meals_perday": 3.0,
    "monitor_calories": "no",
    "parent_overweight": "no",
    "physical_activity_perweek": "1 to 2",
    "siblings": 1,
    "smoke": "no",
    "transportation": "Walk",
    "veggies_freq": "Sometimes",
    "water_daily": "1 to 2",
    "weight": 90.0
}

# %%
df_var.head(1).dtypes
# Out:
# age                          float64
# alcohol_freq                  object
# caloric_freq                  object
# devices_perday                object
# eat_between_meals             object
# gender                        object
# height                       float64
# meals_perday                 float64
# monitor_calories              object
# parent_overweight             object
# physical_activity_perweek     object
# siblings                     float64
# smoke                         object
# transportation                object
# veggies_freq                  object
# water_daily                   object
# weight                       float64
# dtype: object

# %%
x = pd.DataFrame([my_data])
x
# Out:
#     age alcohol_freq caloric_freq devices_perday eat_between_meals gender  \
# 0  20.0       Always           no    more than 5         Sometimes   Male
#
#    height  meals_perday monitor_calories parent_overweight  \
# 0    1.72           3.0               no                no
#
#   physical_activity_perweek  siblings smoke transportation veggies_freq  \
# 0                    1 to 2         1    no           Walk    Sometimes
#
#   water_daily  weight
# 0      1 to 2    90.0

# %%
a, b = run(X_train,x, config_12)
b
# Out:
# c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#         age    height  siblings    weight  alcohol_freq_encoded  \
# 0 -0.683343  0.160452         1  0.094483                   0.0
#
#    caloric_freq_encoded  devices_perday_encoded  meals_perday_encoded  \
# 0                   0.0                     0.0                   2.0
#
#    monitor_calories_encoded  parent_overweight_encoded  \
# 0                       0.0                        0.0
#
#    physical_activity_perweek_encoded  transportation_encoded  \
# 0                                0.0                     4.0
#
#    veggies_freq_encoded  water_daily_encoded  bmi_class_encoded  \
# 0                   2.0                  0.0                1.0
#
#    eat_between_meals_encoded  gender_1.0  smoke_1.0
# 0                        3.0         1.0        0.0

# %%
trees[12].predict(b)
# Out:
# array(['Normal_Weight'], dtype=object)

# %% [markdown]
# Bruh

# %% [markdown]
# # Save data, with best preprocessing configuration

# %%
# Load test csv file
test = pd.read_csv("../data/obesity_test.csv")

# %%
# Preprocess
_, test = run(X_train, test, config_12)
# Out:
# c:\Users\ACER\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:825: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
test = test.drop(columns=["marrital_status", "region"])
test.to_csv("../our data/preprocessed_test.csv")
