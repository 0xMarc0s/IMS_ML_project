# %% [markdown]
# # Preliminary notebook - Data Exploration
# In this notebook I will be exploring the datasets (training data), to look for observations

# %%
# Funny colors and images
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
from IPython.display import Image

# %%
# Pandas, NumPy import and version
import pandas as pd
import numpy as np
print(f"Modules imported.\n Pandas: {pd.__version__}\n Numpy: {np.__version__}")
# Out:
# Modules imported.
#  Pandas: 2.2.2
#  Numpy: 1.26.4

# %%
# Data loading
path = r"../data/"
df = pd.read_csv(path+"obesity_train.csv")
df.head(5)
# Out:
#    id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0   1  21.0        Never           no        up to 5         Sometimes
# 1   2  23.0   Frequently           no        up to 5         Sometimes
# 2   3   NaN   Frequently           no        up to 2         Sometimes
# 3   4  22.0    Sometimes           no        up to 2         Sometimes
# 4   5  22.0    Sometimes           no        up to 2         Sometimes
#
#    gender  height  marrital_status  meals_perday  ... parent_overweight  \
# 0  Female    1.62              NaN           3.0  ...               yes
# 1    Male    1.80              NaN           3.0  ...               yes
# 2    Male    1.80              NaN           3.0  ...                no
# 3    Male    1.78              NaN           1.0  ...                no
# 4    Male    1.64              NaN           3.0  ...                no
#
#   physical_activity_perweek region siblings  smoke transportation  \
# 0                       NaN  LatAm      3.0     no         Public
# 1                    3 to 4  LatAm      0.0     no         Public
# 2                    3 to 4  LatAm      2.0     no           Walk
# 3                       NaN  LatAm      3.0     no         Public
# 4                 5 or more  LatAm      3.0     no         Public
#
#   veggies_freq water_daily weight          obese_level
# 0    Sometimes      1 to 2   64.0        Normal_Weight
# 1    Sometimes      1 to 2   77.0        Normal_Weight
# 2       Always      1 to 2   87.0   Overweight_Level_I
# 3    Sometimes      1 to 2   90.0  Overweight_Level_II
# 4    Sometimes      1 to 2   53.0        Normal_Weight
#
# [5 rows x 21 columns]

# %%
# Data exploration
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1545 non-null   float64
#  2   alcohol_freq               1575 non-null   object
#  3   caloric_freq               1591 non-null   object
#  4   devices_perday             1589 non-null   object
#  5   eat_between_meals          1552 non-null   object
#  6   gender                     1591 non-null   object
#  7   height                     1597 non-null   float64
#  8   marrital_status            0 non-null      float64
#  9   meals_perday               1602 non-null   float64
#  10  monitor_calories           1572 non-null   object
#  11  parent_overweight          1591 non-null   object
#  12  physical_activity_perweek  1046 non-null   object
#  13  region                     1544 non-null   object
#  14  siblings                   1599 non-null   float64
#  15  smoke                      1599 non-null   object
#  16  transportation             1571 non-null   object
#  17  veggies_freq               1585 non-null   object
#  18  water_daily                1577 non-null   object
#  19  weight                     1558 non-null   float64
#  20  obese_level                1611 non-null   object
# dtypes: float64(6), int64(1), object(14)
# memory usage: 264.4+ KB

# %% [markdown]
# **OBSERVATION A.** We immediately notice that we have *missing values*. In particular, `marital_status` is always null. For this reason, the column `marital_status` is to be dropped.
#
# **OBSERVATION B.** Also, we have too many columns which leads us to the *curse of dimensionality*. Feature selection or engineering is to be considered.

# %%
# Count percentage of missing data for each column
missing_hash = {}
total = df.shape[0]
for col in df.columns.tolist():
    missing = df[col].isnull().sum()
    # print(f"Column {col} has {bcolors.FAIL}{bcolors.BOLD}{(missing/total*100).round(2)}%{bcolors.ENDC} of missing data")
    missing_hash[col] = missing/total*100

missing_s = pd.Series(missing_hash)
for x in missing_s:
    print(round(x, 2))
# Out:
# 0.0
# 4.1
# 2.23
# 1.24
# 1.37
# 3.66
# 1.24
# 0.87
# 100.0
# 0.56
# 2.42
# 1.24
# 35.07
# 4.16
# 0.74
# 0.74
# 2.48
# 1.61
# 2.11
# 3.29
# 0.0

# %% [markdown]
# **OBSERVATION C.** Excluding `marital_status`, we have `physical_activity_perweek` with a significant percentage of missing data ($\sim 35\%$). However, as this column might be relevant for our project, it will not be dropped and instead we will attempt to fill it with an algorithm (such as K-means)

# %% [markdown]
# # Visualization
# Now, with Excel (as we don't know how to use matplotlib yet), we will create some data visualizations to get a clearer idea of data. In particular, we're going to focus on quantitative data.

# %%
# 1. Age x Height
Image(r"..\images\ageheight_1.png")
df.query("age<10")
# Out:
#       id  age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 115  116  6.0        Never           no            NaN         Sometimes
#
#     gender  height  marrital_status  meals_perday  ... parent_overweight  \
# 115   Male    2.19              NaN           3.0  ...               yes
#
#     physical_activity_perweek region siblings  smoke transportation  \
# 115                    3 to 4  LatAm      2.0     no            Car
#
#     veggies_freq  water_daily weight          obese_level
# 115    Sometimes  more than 2   84.0  Overweight_Level_II
#
# [1 rows x 21 columns]

# %% [markdown]
# **OBSERVATION D.** We have clear potentials for multidimensional outliers, such as 7-year ols kids tall as 2.3 meters. As normal outliers, we only have a $<10$-year old, $>85$-year old and people shorter than $1.5$ meters. To detect our multidimensional outliers better, we will use Kmeans.

# %%
Image(r"../images/avg_meal_1.png")

# %% [markdown]
# **OBSERVATION E.** It seems to be centered around $\mu=3$, in particular we have

# %%
df.meals_perday.describe()
# Out:
# count    1602.000000
# mean        2.684145
# std         0.817584
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: meals_perday, dtype: float64

# %% [markdown]
# This means we can treat people with 1 or 4 meals a day as outliers.

# %%
df.obese_level.value_counts()
# Out:
# obese_level
# Obesity_Type_I         269
# Obesity_Type_III       240
# Obesity_Type_II        232
# Overweight_Level_II    226
# Overweight_Level_I     225
# Normal_Weight          222
# Insufficient_Weight    197
# Name: count, dtype: int64

# %% [markdown]
# # OTHER IDEAS
# - Look at how categorical (boolean) data affect the data variable, such as eating in between meals, etc...
# - How to treat outliers?
# - How to fill missing data? If KNN, basing on which other columns?

# %%
x = df.drop("marrital_status", axis=1 )
x = x.drop("id", axis=1)
x = x.isna()
x['missing'] = x.sum(axis=1)
x.sort_values(by="missing", ascending=True)
y = x.query("missing==0")

df_filtered = (df.drop("marrital_status", axis=1)).dropna()
df_filtered.to_csv("../our data/simple.csv")

# %% [markdown]
# we can train a regression (or model) basing only on "simplistic data" (with non-missing rows)

# %% [markdown]
# **Transforming categorical data into numerical with stuff**

# %%
df_filtered
# Out:
#         id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 1        2  23.0   Frequently           no        up to 5         Sometimes
# 4        5  22.0    Sometimes           no        up to 2         Sometimes
# 5        6  24.0   Frequently          yes        up to 5         Sometimes
# 7        8  22.0    Sometimes           no        up to 2         Sometimes
# 8        9  41.0   Frequently          yes        up to 5         Sometimes
# ...    ...   ...          ...          ...            ...               ...
# 1590  1591  22.0    Sometimes          yes        up to 5         Sometimes
# 1605  1606  22.0    Sometimes          yes        up to 5         Sometimes
# 1608  1609  23.0    Sometimes          yes        up to 5         Sometimes
# 1609  1610  24.0    Sometimes          yes        up to 5         Sometimes
# 1610  1611  24.0    Sometimes          yes        up to 5         Sometimes
#
#       gender  height  meals_perday monitor_calories parent_overweight  \
# 1       Male    1.80           3.0               no               yes
# 4       Male    1.64           3.0               no                no
# 5       Male    1.78           3.0               no               yes
# 7       Male    1.65           3.0               no                no
# 8       Male    1.80           3.0               no                no
# ...      ...     ...           ...              ...               ...
# 1590  Female    1.75           3.0               no               yes
# 1605  Female    1.73           3.0               no               yes
# 1608  Female    1.75           3.0               no               yes
# 1609  Female    1.74           3.0               no               yes
# 1610  Female    1.74           3.0               no               yes
#
#      physical_activity_perweek region  siblings smoke transportation  \
# 1                       3 to 4  LatAm       0.0    no         Public
# 4                    5 or more  LatAm       3.0    no         Public
# 5                       1 to 2  LatAm       2.0    no         Public
# 7                       3 to 4  LatAm       1.0    no         Public
# 8                       3 to 4  LatAm       0.0    no            Car
# ...                        ...    ...       ...   ...            ...
# 1590                    1 to 2  LatAm       3.0    no         Public
# 1605                    3 to 4  LatAm       2.0    no         Public
# 1608                    1 to 2  LatAm       0.0    no         Public
# 1609                    1 to 2  LatAm       0.0    no         Public
# 1610                    1 to 2  LatAm       0.0    no         Public
#
#      veggies_freq  water_daily  weight       obese_level
# 1       Sometimes       1 to 2    77.0     Normal_Weight
# 4       Sometimes       1 to 2    53.0     Normal_Weight
# 5          Always       1 to 2    64.0     Normal_Weight
# 7          Always  more than 2    56.0     Normal_Weight
# 8       Sometimes       1 to 2    99.0    Obesity_Type_I
# ...           ...          ...     ...               ...
# 1590       Always  more than 2   134.0  Obesity_Type_III
# 1605       Always       1 to 2   133.0  Obesity_Type_III
# 1608       Always       1 to 2   134.0  Obesity_Type_III
# 1609       Always  more than 2   133.0  Obesity_Type_III
# 1610       Always  more than 2   133.0  Obesity_Type_III
#
# [734 rows x 20 columns]

# %%
categorical_df = df.copy()
categorical_df
# Out:
#         id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0        1  21.0        Never           no        up to 5         Sometimes
# 1        2  23.0   Frequently           no        up to 5         Sometimes
# 2        3   NaN   Frequently           no        up to 2         Sometimes
# 3        4  22.0    Sometimes           no        up to 2         Sometimes
# 4        5  22.0    Sometimes           no        up to 2         Sometimes
# ...    ...   ...          ...          ...            ...               ...
# 1606  1607  21.0    Sometimes          NaN        up to 5         Sometimes
# 1607  1608  22.0    Sometimes          yes        up to 5         Sometimes
# 1608  1609  23.0    Sometimes          yes        up to 5         Sometimes
# 1609  1610  24.0    Sometimes          yes        up to 5         Sometimes
# 1610  1611  24.0    Sometimes          yes        up to 5         Sometimes
#
#       gender  height  marrital_status  meals_perday  ... parent_overweight  \
# 0     Female    1.62              NaN           3.0  ...               yes
# 1       Male    1.80              NaN           3.0  ...               yes
# 2       Male    1.80              NaN           3.0  ...                no
# 3       Male    1.78              NaN           1.0  ...                no
# 4       Male    1.64              NaN           3.0  ...                no
# ...      ...     ...              ...           ...  ...               ...
# 1606  Female    1.73              NaN           3.0  ...               yes
# 1607  Female    1.75              NaN           3.0  ...               yes
# 1608  Female    1.75              NaN           3.0  ...               yes
# 1609  Female    1.74              NaN           3.0  ...               yes
# 1610  Female    1.74              NaN           3.0  ...               yes
#
#      physical_activity_perweek region siblings  smoke transportation  \
# 0                          NaN  LatAm      3.0     no         Public
# 1                       3 to 4  LatAm      0.0     no         Public
# 2                       3 to 4  LatAm      2.0     no           Walk
# 3                          NaN  LatAm      3.0     no         Public
# 4                    5 or more  LatAm      3.0     no         Public
# ...                        ...    ...      ...    ...            ...
# 1606                    3 to 4  LatAm      1.0     no         Public
# 1607                    1 to 2  LatAm      0.0     no            NaN
# 1608                    1 to 2  LatAm      0.0     no         Public
# 1609                    1 to 2  LatAm      0.0     no         Public
# 1610                    1 to 2  LatAm      0.0     no         Public
#
#      veggies_freq  water_daily weight          obese_level
# 0       Sometimes       1 to 2   64.0        Normal_Weight
# 1       Sometimes       1 to 2   77.0        Normal_Weight
# 2          Always       1 to 2   87.0   Overweight_Level_I
# 3       Sometimes       1 to 2   90.0  Overweight_Level_II
# 4       Sometimes       1 to 2   53.0        Normal_Weight
# ...           ...          ...    ...                  ...
# 1606       Always       1 to 2  131.0     Obesity_Type_III
# 1607       Always       1 to 2  134.0     Obesity_Type_III
# 1608       Always       1 to 2  134.0     Obesity_Type_III
# 1609       Always  more than 2  133.0     Obesity_Type_III
# 1610       Always  more than 2  133.0     Obesity_Type_III
#
# [1611 rows x 21 columns]

# %%
df[column] = df[column].astype(category)
df[column] = df[column].cat.codes
