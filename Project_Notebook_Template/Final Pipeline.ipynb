# %% [markdown]
# <b><font size="6">Predictive Modelling Pipeline Template</font></b><br><br>

# %% [markdown]
# In this notebook we present to you the main steps you should follow throughout your project.
#
#
# <b> Important: The numbered sections and subsections are merely indicative of some of the steps you should pay attention to in your project. <br>You are not required to strictly follow this order or to execute everything in separate cells.</b>
#
# <img src="image/process_ML.png" style="height:70px">

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, RobustScaler
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a class="anchor" id="">
#
# # 1. Import data (Data Integration)
#
# </a>

# %% [markdown]
# <img src="image/step1.png" style="height:60px">

# %%
# Load the data in a simple way
obesity_train_raw = pd.read_csv('../data/obesity_train.csv')
obesity_test_raw = pd.read_csv('../data/obesity_test.csv')

# %%
obesity_train_raw.head(10)
# Out:
#    id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0   1  21.0        Never           no        up to 5         Sometimes
# 1   2  23.0   Frequently           no        up to 5         Sometimes
# 2   3   NaN   Frequently           no        up to 2         Sometimes
# 3   4  22.0    Sometimes           no        up to 2         Sometimes
# 4   5  22.0    Sometimes           no        up to 2         Sometimes
# 5   6  24.0   Frequently          yes        up to 5         Sometimes
# 6   7  21.0    Sometimes          yes        up to 5        Frequently
# 7   8  22.0    Sometimes           no        up to 2         Sometimes
# 8   9  41.0   Frequently          yes        up to 5         Sometimes
# 9  10  27.0    Sometimes          yes        up to 2         Sometimes
#
#    gender  height  marrital_status  meals_perday  ... parent_overweight  \
# 0  Female    1.62              NaN           3.0  ...               yes
# 1    Male    1.80              NaN           3.0  ...               yes
# 2    Male    1.80              NaN           3.0  ...                no
# 3    Male    1.78              NaN           1.0  ...                no
# 4    Male    1.64              NaN           3.0  ...                no
# 5    Male    1.78              NaN           3.0  ...               yes
# 6  Female    1.72              NaN           3.0  ...               yes
# 7    Male    1.65              NaN           3.0  ...                no
# 8    Male    1.80              NaN           3.0  ...                no
# 9    Male    1.93              NaN           1.0  ...               yes
#
#   physical_activity_perweek region siblings  smoke transportation  \
# 0                       NaN  LatAm      3.0     no         Public
# 1                    3 to 4  LatAm      0.0     no         Public
# 2                    3 to 4  LatAm      2.0     no           Walk
# 3                       NaN  LatAm      3.0     no         Public
# 4                 5 or more  LatAm      3.0     no         Public
# 5                    1 to 2  LatAm      2.0     no         Public
# 6                    3 to 4    NaN      2.0     no         Public
# 7                    3 to 4  LatAm      1.0     no         Public
# 8                    3 to 4  LatAm      0.0     no            Car
# 9                    1 to 2  LatAm      2.0     no         Public
#
#   veggies_freq  water_daily weight          obese_level
# 0    Sometimes       1 to 2   64.0        Normal_Weight
# 1    Sometimes       1 to 2   77.0        Normal_Weight
# 2       Always       1 to 2   87.0   Overweight_Level_I
# 3    Sometimes       1 to 2   90.0  Overweight_Level_II
# 4    Sometimes       1 to 2   53.0        Normal_Weight
# 5       Always       1 to 2   64.0        Normal_Weight
# 6    Sometimes       1 to 2   80.0  Overweight_Level_II
# 7       Always  more than 2   56.0        Normal_Weight
# 8    Sometimes       1 to 2   99.0       Obesity_Type_I
# 9    Sometimes  less than 1  102.0  Overweight_Level_II
#
# [10 rows x 21 columns]

# %%
obesity_test_raw.head(10)
# Out:
#      id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0  1612  21.0    Sometimes           no        up to 2         Sometimes
# 1  1613  29.0    Sometimes          yes        up to 2         Sometimes
# 2  1614  23.0    Sometimes          NaN        up to 2         Sometimes
# 3  1615  22.0        Never          yes        up to 5         Sometimes
# 4  1616  26.0    Sometimes          yes    more than 5        Frequently
# 5  1617  23.0    Sometimes          yes        up to 5         Sometimes
# 6  1618  22.0    Sometimes           no        up to 5            Always
# 7  1619  29.0        Never          yes        up to 2         Sometimes
# 8  1620  30.0        Never          yes        up to 2        Frequently
# 9  1621  23.0    Sometimes          yes        up to 5        Frequently
#
#    gender  height  marrital_status  meals_perday monitor_calories  \
# 0  Female    1.52              NaN           3.0              yes
# 1    Male    1.62              NaN           3.0               no
# 2  Female    1.50              NaN           3.0               no
# 3    Male    1.72              NaN           3.0               no
# 4    Male    1.85              NaN           3.0               no
# 5    Male    1.77              NaN           1.0               no
# 6  Female    1.70              NaN           3.0              yes
# 7  Female    1.53              NaN           1.0               no
# 8  Female    1.71              NaN           4.0               no
# 9  Female    1.60              NaN           4.0               no
#
#   parent_overweight physical_activity_perweek region  siblings smoke  \
# 0               yes                 5 or more  LatAm       3.0   yes
# 1                no                       NaN  LatAm       3.0    no
# 2               yes                    1 to 2  LatAm       2.0    no
# 3               yes                    1 to 2  LatAm       1.0    no
# 4               yes                    3 to 4  LatAm       1.0    no
# 5               yes                    1 to 2  LatAm       2.0    no
# 6               yes                    3 to 4  LatAm       1.0    no
# 7                no                       NaN  LatAm       0.0    no
# 8               yes                       NaN  LatAm       0.0   yes
# 9                no                    3 to 4  LatAm       3.0    no
#
#   transportation veggies_freq  water_daily  weight
# 0         Public       Always  more than 2    56.0
# 1            Car    Sometimes       1 to 2    53.0
# 2      Motorbike       Always       1 to 2     NaN
# 3         Public    Sometimes       1 to 2    68.0
# 4         Public       Always  more than 2   105.0
# 5         Public       Always  less than 1    60.0
# 6         Public       Always       1 to 2     NaN
# 7            Car    Sometimes       1 to 2    78.0
# 8            Car       Always  less than 1    82.0
# 9            Car    Sometimes       1 to 2    52.0

# %% [markdown]
# <a class="anchor" id="">
#
# # 2. Explore data (Data access, exploration and understanding)
#
# </a>

# %% [markdown]
# <img src="image/step2.png" style="height:60px">

# %% [markdown]
# Remember, this step is very important as it is at this stage that you will really look into the data that you have. Generally speaking, if you do well at this stage, the following stages will be very smooth.
#
# Moreover, you should also take the time to find meaningful patterns on the data: what interesting relationships can be found between the variables and how can that knowledge be inform your future decisions.

# %%
# Display information about the training dataset
obesity_train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1545 non-null   float64
#  2   alcohol_freq               1575 non-null   object
#  3   caloric_freq               1591 non-null   object
#  4   devices_perday             1589 non-null   object
#  5   eat_between_meals          1552 non-null   object
#  6   gender                     1591 non-null   object
#  7   height                     1597 non-null   float64
#  8   marrital_status            0 non-null      float64
#  9   meals_perday               1602 non-null   float64
#  10  monitor_calories           1572 non-null   object
#  11  parent_overweight          1591 non-null   object
#  12  physical_activity_perweek  1046 non-null   object
#  13  region                     1544 non-null   object
#  14  siblings                   1599 non-null   float64
#  15  smoke                      1599 non-null   object
#  16  transportation             1571 non-null   object
#  17  veggies_freq               1585 non-null   object
#  18  water_daily                1577 non-null   object
#  19  weight                     1558 non-null   float64
#  20  obese_level                1611 non-null   object
# dtypes: float64(6), int64(1), object(14)
# memory usage: 264.4+ KB

# %% [markdown]
# <a class="anchor" id="">
#
# # 3. Modify data (Data preparation)
#
# </a>

# %% [markdown]
# <img src="image/step3.png" style="height:60px">

# %% [markdown]
# Use this section to apply transformations to your dataset.
#
# Remember that your decisions at this step should be exclusively informed by your **training data**. While you will need to split your data between training and validation, how that split will be made and how to apply the approppriate transformations will depend on the type of model assessment solution you select for your project (each has its own set of advantages and disadvantages that you need to consider). **Please find a list of possible methods for model assessment below**:
#
# 1. **Holdout method**
# 2. **Repeated Holdout method**
# 3. **Cross-Validation**
#
# __Note:__ Instead of creating different sections for the treatment of training and validation data, you can make the transformations in the same cell. There is no need to create a specific section for that.

# %% [markdown]
# ### 3.1. Data Preparation

# %%
# Drop the 'marrital_status' and 'region' columns from the dataset
obesity_train = obesity_train_raw.drop(columns=['marrital_status', 'region'])
obesity_test = obesity_test_raw.drop(columns=['marrital_status', 'region'])

# %%
obesity_train.set_index('id', inplace=True)
obesity_test.set_index('id', inplace=True)
obesity_train
# Out:
#        age alcohol_freq caloric_freq devices_perday eat_between_meals  gender  \
# id
# 1     21.0        Never           no        up to 5         Sometimes  Female
# 2     23.0   Frequently           no        up to 5         Sometimes    Male
# 3      NaN   Frequently           no        up to 2         Sometimes    Male
# 4     22.0    Sometimes           no        up to 2         Sometimes    Male
# 5     22.0    Sometimes           no        up to 2         Sometimes    Male
# ...    ...          ...          ...            ...               ...     ...
# 1607  21.0    Sometimes          NaN        up to 5         Sometimes  Female
# 1608  22.0    Sometimes          yes        up to 5         Sometimes  Female
# 1609  23.0    Sometimes          yes        up to 5         Sometimes  Female
# 1610  24.0    Sometimes          yes        up to 5         Sometimes  Female
# 1611  24.0    Sometimes          yes        up to 5         Sometimes  Female
#
#       height  meals_perday monitor_calories parent_overweight  \
# id
# 1       1.62           3.0               no               yes
# 2       1.80           3.0               no               yes
# 3       1.80           3.0               no                no
# 4       1.78           1.0               no                no
# 5       1.64           3.0               no                no
# ...      ...           ...              ...               ...
# 1607    1.73           3.0               no               yes
# 1608    1.75           3.0               no               yes
# 1609    1.75           3.0               no               yes
# 1610    1.74           3.0               no               yes
# 1611    1.74           3.0               no               yes
#
#      physical_activity_perweek  siblings smoke transportation veggies_freq  \
# id
# 1                          NaN       3.0    no         Public    Sometimes
# 2                       3 to 4       0.0    no         Public    Sometimes
# 3                       3 to 4       2.0    no           Walk       Always
# 4                          NaN       3.0    no         Public    Sometimes
# 5                    5 or more       3.0    no         Public    Sometimes
# ...                        ...       ...   ...            ...          ...
# 1607                    3 to 4       1.0    no         Public       Always
# 1608                    1 to 2       0.0    no            NaN       Always
# 1609                    1 to 2       0.0    no         Public       Always
# 1610                    1 to 2       0.0    no         Public       Always
# 1611                    1 to 2       0.0    no         Public       Always
#
#       water_daily  weight          obese_level
# id
# 1          1 to 2    64.0        Normal_Weight
# 2          1 to 2    77.0        Normal_Weight
# 3          1 to 2    87.0   Overweight_Level_I
# 4          1 to 2    90.0  Overweight_Level_II
# 5          1 to 2    53.0        Normal_Weight
# ...           ...     ...                  ...
# 1607       1 to 2   131.0     Obesity_Type_III
# 1608       1 to 2   134.0     Obesity_Type_III
# 1609       1 to 2   134.0     Obesity_Type_III
# 1610  more than 2   133.0     Obesity_Type_III
# 1611  more than 2   133.0     Obesity_Type_III
#
# [1611 rows x 18 columns]

# %%
# Selecting outliers for which the age is out of scope. Or the weight classification is suspiciously low for the value given
outliers = obesity_train[
    ((obesity_train['age'] < 16) & ~(obesity_train['age'].isna())) |
    ((obesity_train['age'] > 56) & ~(obesity_train['age'].isna())) |
    ((obesity_train['weight'] > 167) & ~(obesity_train['weight'].isna()))
]
obesity_train.drop(outliers.index, inplace=True)
obesity_train.reset_index(drop=True, inplace=True)

# %%
obesity_train.shape # Shape adds up to our expectation (6 rows deleted) 1611 -> 1605 rows
# Out:
# (1605, 18)

# %% [markdown]
# # Encoding categorical data

# %%
categorical_columns = obesity_train.select_dtypes(include='object').columns
numerical_columns = obesity_train.select_dtypes(exclude='object').columns

# %%
obesity_train.columns
# Out:
# Index(['age', 'alcohol_freq', 'caloric_freq', 'devices_perday',
#        'eat_between_meals', 'gender', 'height', 'meals_perday',
#        'monitor_calories', 'parent_overweight', 'physical_activity_perweek',
#        'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily',
#        'weight', 'obese_level'],
#       dtype='object')

# %%
# Impute with mode and median as the first null-handling resolution. Will be re-approached with further iterations on the model itself

obesity_train['physical_activity_perweek'].fillna(0, inplace=True) # ASSUMPTION: There is no 0 value in the scope. We assume nulls are the people who dont work out

# %%
hashmap = {
"Never": 0,
"Sometimes": 1,
"Frequently": 2,
"Always": 3,

"No Activity": 0,
"up to 2": 1,
"up to 5": 2,
"more than 5": 3,

"less than 1": 1,
"1 to 2": 2,
"more than 2": 3,
"3 to 4": 4,
"5 or more": 5,

"Bicycle": 1,
"Car": 3,
"Motorbike": 3,
"Public": 2,
"Walk": 0,

"no": 0,
"yes": 1,

"Male": 0,
"Female": 1
}

# %%
# Manually encode data

columns = ['alcohol_freq',
 'caloric_freq',
 'devices_perday',
 'eat_between_meals',
 'gender',
 'monitor_calories',
 'parent_overweight',
 'physical_activity_perweek',
 'smoke',
 'transportation',
 'veggies_freq',
 'water_daily',
 'meals_perday',
 "siblings"]

for target in columns:
    obesity_train[target] = obesity_train[target].replace(hashmap)

# %%
obesity_train_encoded = obesity_train.copy()
obesity_train_encoded.isna().sum()
# Out:
# age                          65
# alcohol_freq                 36
# caloric_freq                 20
# devices_perday               21
# eat_between_meals            59
# gender                       20
# height                       13
# meals_perday                  9
# monitor_calories             39
# parent_overweight            20
# physical_activity_perweek     0
# siblings                     12
# smoke                        12
# transportation               40
# veggies_freq                 26
# water_daily                  34
# weight                       53
# obese_level                   0
# dtype: int64

# %% [markdown]
# # Handling Missing Values

# %%
obesity_train_encoded.head(3)
# Out:
#     age  alcohol_freq  caloric_freq  devices_perday  eat_between_meals  \
# 0  21.0           0.0           0.0             2.0                1.0
# 1  23.0           2.0           0.0             2.0                1.0
# 2   NaN           2.0           0.0             1.0                1.0
#
#    gender  height  meals_perday  monitor_calories  parent_overweight  \
# 0     1.0    1.62           3.0               0.0                1.0
# 1     0.0    1.80           3.0               0.0                1.0
# 2     0.0    1.80           3.0               0.0                0.0
#
#    physical_activity_perweek  siblings  smoke  transportation  veggies_freq  \
# 0                          0       3.0    0.0             2.0           1.0
# 1                          4       0.0    0.0             2.0           1.0
# 2                          4       2.0    0.0             0.0           3.0
#
#    water_daily  weight         obese_level
# 0          2.0    64.0       Normal_Weight
# 1          2.0    77.0       Normal_Weight
# 2          2.0    87.0  Overweight_Level_I

# %%
from sklearn.model_selection import train_test_split

X = obesity_train_encoded.drop(columns='obese_level')
y = obesity_train_encoded[['obese_level']]

# %%
X.isna().sum()
# Out:
# age                          65
# alcohol_freq                 36
# caloric_freq                 20
# devices_perday               21
# eat_between_meals            59
# gender                       20
# height                       13
# meals_perday                  9
# monitor_calories             39
# parent_overweight            20
# physical_activity_perweek     0
# siblings                     12
# smoke                        12
# transportation               40
# veggies_freq                 26
# water_daily                  34
# weight                       53
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

# Create copies for KNN imputation
data_knnimputer_train = X.copy()

# Specify the columns to scale
numerical_columns_features = numerical_columns

# Scale the data for KNN imputation
scaler = StandardScaler()
data_knnimputer_train[numerical_columns_features] = scaler.fit_transform(data_knnimputer_train[numerical_columns_features])

# Perform KNN imputation
knn_imputer = KNNImputer(n_neighbors=5, weights='uniform')
data_knnimputer_train[numerical_columns_features] = knn_imputer.fit_transform(data_knnimputer_train[numerical_columns_features])

# Inverse transform to original scale
data_knnimputer_train[numerical_columns_features] = scaler.inverse_transform(data_knnimputer_train[numerical_columns_features])

# Check for any remaining missing values
print(data_knnimputer_train.isna().sum())
# Out:
# age                           0
# alcohol_freq                 36
# caloric_freq                 20
# devices_perday               21
# eat_between_meals            59
# gender                       20
# height                        0
# meals_perday                  0
# monitor_calories             39
# parent_overweight            20
# physical_activity_perweek     0
# siblings                      0
# smoke                        12
# transportation               40
# veggies_freq                 26
# water_daily                  34
# weight                        0
# dtype: int64

# %% [markdown]
# Add BMI

# %%
def classify_bmi_comprehensive(row):
    """
    Classify BMI based on age and BMI value.

    Input:
    row: A Pandas row with 'weight', 'height', and 'age' columns.

    Output:
    Returns a string that classifies the individual into BMI categories.
    """
    # Check if weight and height are valid
    if row['height'] <= 0 or row['weight'] <= 0:
        return 'Invalid data'

    # Calculate BMI
    bmi = row['weight'] / (row['height'] ** 2)

    # Age group: Children (2-19 years)
    if 2 <= row['age'] < 20:
        if bmi < 14:
            return 0 # Underweight
        elif 14 <= bmi < 18:
            return 1 # Normal weight
        elif 18 <= bmi < 21:
            return 2 # Overweight
        else:
            return 3 # Obesity 1

    # Age group: Adults (20-64 years)
    elif 20 <= row['age'] < 65:
        if bmi < 18.5:
            return 0 # "Underweight"
        elif 18.5 <= bmi < 25:
            return 1 # "Healthy Weight"
        elif 25 <= bmi < 30:
            return 2 #"Overweight"
        elif 30<= bmi < 35:
            return 3 #"Obese Class 1"
        elif 35 <= bmi < 40:
            return 4 #"Obese Class 2"
        else:
            return 5 #"Obese Class 3"

# %%
data_knnimputer_train['bmi_class'] = data_knnimputer_train.apply(lambda row: classify_bmi_comprehensive(row), axis=1)

# %% [markdown]
# # Manually encode the bmi

# %%
hash_obesity = {
 'Normal_Weight': 1,
 'Overweight_Level_I': 2,
 'Overweight_Level_II': 3,
 'Obesity_Type_I': 4,
 'Insufficient_Weight': 5,
 'Obesity_Type_II': 6,
 'Obesity_Type_III': 7
 }

y = y['obese_level'].replace(hash_obesity)

# %% [markdown]
# Impute categorical

# %%
data_knnimputer_train.head(2)
# Out:
#     age  alcohol_freq  caloric_freq  devices_perday  eat_between_meals  \
# 0  21.0           0.0           0.0             2.0                1.0
# 1  23.0           2.0           0.0             2.0                1.0
#
#    gender  height  meals_perday  monitor_calories  parent_overweight  \
# 0     1.0    1.62           3.0               0.0                1.0
# 1     0.0    1.80           3.0               0.0                1.0
#
#    physical_activity_perweek  siblings  smoke  transportation  veggies_freq  \
# 0                          0       3.0    0.0             2.0           1.0
# 1                          4       0.0    0.0             2.0           1.0
#
#    water_daily  weight  bmi_class
# 0          2.0    64.0          1
# 1          2.0    77.0          1

# %%
categorical_columns = categorical_columns.drop('obese_level')

# %%
from sklearn.experimental import enable_iterative_imputer  # Enable IterativeImputer
from sklearn.impute import IterativeImputer
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# Initialize IterativeImputer with KNeighborsClassifier for categorical data imputation
iterative_imputer = IterativeImputer(estimator=KNeighborsClassifier(n_neighbors=5), max_iter=10, random_state=42, 
                                     skip_complete=True)

# Perform imputation on the encoded categorical data
data_knnimputer_train_imputed = iterative_imputer.fit_transform(data_knnimputer_train)

# Convert back to DataFrame and assign original column names
data_knnimputer_train = pd.DataFrame(data_knnimputer_train_imputed, columns=data_knnimputer_train.columns)

# Check for any remaining missing values
print(data_knnimputer_train[categorical_columns].isna().sum())
# Out:
# alcohol_freq                 0
# caloric_freq                 0
# devices_perday               0
# eat_between_meals            0
# gender                       0
# monitor_calories             0
# parent_overweight            0
# physical_activity_perweek    0
# smoke                        0
# transportation               0
# veggies_freq                 0
# water_daily                  0
# dtype: int64

# %%
encoded_train = data_knnimputer_train.copy()

# %%
# Transform to life score
life_columns = [
 'alcohol_freq',
 'caloric_freq',
 'devices_perday',
 'eat_between_meals',
 'monitor_calories',
 'physical_activity_perweek',
 'smoke',
 'transportation',
 'veggies_freq',
 'water_daily',
 ]

encoded_train["life"] = 0

for column in life_columns:
    encoded_train["life"] += encoded_train[column]

# %% [markdown]
# ### 3.3. Scaling

# %% [markdown]
# # Value scaling - finally done at the level of each fold so no prior scaling needed
#
# from sklearn.preprocessing import StandardScaler
#
# scale_age = StandardScaler().fit(encoded_train[["age"]])
# scale_height = StandardScaler().fit(encoded_train[["height"]])
# scale_weight = StandardScaler().fit(encoded_train[["weight"]]) # Statistical analysis justifies the need to use RobustScaler on this one
#
# dfs = [encoded_train] # Transform both dataframes
# for df in dfs:
#     new_age = scale_age.transform(df[["age"]])
#     new_height = scale_height.transform(df[["height"]])
#     new_weight = scale_weight.transform(df[["weight"]])
#
#     # Replace columns
#     df["age"] = new_age
#     df["height"] = new_height
#     df["weight"] = new_weight

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
#
# columns_to_scale = encoded_train.columns
# scaler = StandardScaler()
#
# encoded_train[columns_to_scale] = scaler.fit_transform(encoded_train[columns_to_scale])

# %% [markdown]
# ### 3.4. Feature Selection

# %%
obesity_train_preproc = encoded_train.copy()

# %%
obesity_train_preproc.head(3)
# Out:
#     age  alcohol_freq  caloric_freq  devices_perday  eat_between_meals  \
# 0  21.0           0.0           0.0             2.0                1.0
# 1  23.0           2.0           0.0             2.0                1.0
# 2  22.2           2.0           0.0             1.0                1.0
#
#    gender  height  meals_perday  monitor_calories  parent_overweight  \
# 0     1.0    1.62           3.0               0.0                1.0
# 1     0.0    1.80           3.0               0.0                1.0
# 2     0.0    1.80           3.0               0.0                0.0
#
#    physical_activity_perweek  siblings  smoke  transportation  veggies_freq  \
# 0                        0.0       3.0    0.0             2.0           1.0
# 1                        4.0       0.0    0.0             2.0           1.0
# 2                        4.0       2.0    0.0             0.0           3.0
#
#    water_daily  weight  bmi_class  life
# 0          2.0    64.0        1.0   8.0
# 1          2.0    77.0        1.0  14.0
# 2          2.0    87.0        2.0  13.0

# %%
X_train = obesity_train_preproc.copy()
y_train = y.copy()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, f1_score
from sklearn.preprocessing import StandardScaler

# Initialize the Decision Tree model
tree = RandomForestClassifier(random_state=42)

# Initialize StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Perform Stratified K-Fold Cross Validation
f1_scores = []

for train_index, val_index in skf.split(X_train, y_train):
    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
    
    # Initialize the scaler
    scaler = StandardScaler()
    
    # Fit the scaler on the training fold and transform both training and validation folds
    X_train_fold = scaler.fit_transform(X_train_fold)
    X_val_fold = scaler.transform(X_val_fold)
    
    # Fit the model on the training fold
    tree.fit(X_train_fold, y_train_fold)
    
    # Predict on the validation fold
    y_pred_fold = tree.predict(X_val_fold)
    
    # Calculate F1 score
    f1 = f1_score(y_val_fold, y_pred_fold, average='macro')
    f1_scores.append(f1)

# Print the average F1 score
print(f"Average F1 Score: {np.mean(f1_scores)}")
# Out:
# Average F1 Score: 0.9402411494955224

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import StratifiedKFold

# Initialize the Gradient Boosting model
tree_gb = GradientBoostingClassifier(random_state=42)

# Initialize StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Perform Stratified K-Fold Cross Validation
f1_scores = []

for train_index, val_index in skf.split(X_train, y_train):
    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
    
    # Initialize the scaler
    scaler = StandardScaler()
    
    # Fit the scaler on the training fold and transform both training and validation folds
    X_train_fold = scaler.fit_transform(X_train_fold)
    X_val_fold = scaler.transform(X_val_fold)

    # Fit the model on the training fold
    tree_gb.fit(X_train_fold, y_train_fold)
    
    # Predict on the validation fold
    y_pred_fold = tree_gb.predict(X_val_fold)
    
    # Calculate F1 score
    f1 = f1_score(y_val_fold, y_pred_fold, average='macro')
    f1_scores.append(f1)

# Print the average F1 score
print(f"Average F1 Score: {np.mean(f1_scores)}")
# Out:
# Average F1 Score: 0.9446908138758398

# %% [markdown]
# # RFE feature selection

# %%
importances = tree_gb.feature_importances_

importances_df = pd.DataFrame(importances, index=X_train.columns, columns=['importance'])
importances_df = importances_df.sort_values('importance', ascending=False)
importances_df

# %%
import numpy as np
from sklearn.feature_selection import RFE
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

nof_list = np.arange(1, len(X_train.columns) + 1)
high_score = float('-inf')  # Higher is better for F1 score
nof = 0  # Variable to store the optimum number of features
score_list = []

# Store the best selected features for display
best_features = None

# Initialize StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

for n in tqdm(nof_list):
    fold_scores = []
    for train_index, val_index in skf.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        
        # Initialize the scaler
        scaler = StandardScaler()
        
        # Fit the scaler on the training fold and transform both training and validation folds
        X_train_fold = scaler.fit_transform(X_train_fold)
        X_val_fold = scaler.transform(X_val_fold)
        
        model = RandomForestClassifier(random_state=42)
        rfe = RFE(model, n_features_to_select=n)
        X_train_rfe = rfe.fit_transform(X_train_fold, y_train_fold)
        X_val_rfe = rfe.transform(X_val_fold)

        model.fit(X_train_rfe, y_train_fold)
        y_pred = model.predict(X_val_rfe)
        
        # Use F1 score with 'macro' average for multiclass classification
        score = f1_score(y_val_fold, y_pred, average='macro')
        fold_scores.append(score)
    
    avg_score = np.mean(fold_scores)
    score_list.append(avg_score)
    
    # Check if this number of features gives a better score
    if avg_score > high_score:  # Higher is better for F1 score
        high_score = avg_score
        nof = n
        best_features = rfe.get_support()  # Get the mask of selected features

# Display the best results
print("Optimum number of features: %d" % nof)
print("Highest F1 score with %d features: %f" % (nof, high_score))

# Convert columns to a numpy array before using the boolean mask
selected_feature_names = X_train.columns.to_numpy()[best_features]
print("Selected features with %d features:" % nof)
print(selected_feature_names)
# Out:
# 100%|██████████| 19/19 [07:26<00:00, 23.48s/it]
# Optimum number of features: 17
# Highest F1 score with 17 features: 0.942982
# Selected features with 17 features:
# ['age' 'alcohol_freq' 'caloric_freq' 'devices_perday' 'eat_between_meals'
#  'gender' 'height' 'meals_perday' 'parent_overweight'
#  'physical_activity_perweek' 'siblings' 'transportation' 'veggies_freq'
#  'water_daily' 'weight' 'bmi_class' 'life']

# %%
X_train.columns
# Out:
# Index(['age', 'alcohol_freq', 'caloric_freq', 'devices_perday',
#        'eat_between_meals', 'gender', 'height', 'meals_perday',
#        'monitor_calories', 'parent_overweight', 'physical_activity_perweek',
#        'siblings', 'smoke', 'transportation', 'veggies_freq', 'water_daily',
#        'weight', 'bmi_class', 'life'],
#       dtype='object')

# %%
len(X_train.columns)
# Out:
# 19

# %% [markdown]
# # Exhaustive feature selection
# it is the one that tries every possibility so it runs soooo long but is the most accurate:)

# %%
#!pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\wojci\anaconda3\envs\machine-learning\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.2-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 14.0 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.2

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

# List of must-have features
must_have_features = ['age', 'gender', 'height', 'weight', 'bmi_class']

# Separate the features for selection from the must-have features
other_features = [col for col in X_train.columns if col not in must_have_features]

# Initialize the model
model = GradientBoostingClassifier(random_state=42)

# Set up the exhaustive feature selector, where 'other_features' will vary while 'must_have_features' remain
efs = ExhaustiveFeatureSelector(
    estimator=model,
    min_features=1,  # Start with single feature combinations of 'other_features'
    max_features=len(other_features),
    scoring='f1_macro',
    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
    n_jobs=-1  # Use all available CPU cores
)

# Combine the must-have features with other features and scale them in each fold to avoid leakage
# Track progress with tqdm
with tqdm(total=len(other_features)) as progress_bar:
    # Fit the feature selector on the dataset that includes both must-have and other features
    efs = efs.fit(X_train[other_features + must_have_features], y_train)
    progress_bar.update(len(other_features))

# Get the best feature subset found by the selector, which includes combinations of other features and must-have features
selected_features = list(efs.best_feature_names_)

# Ensure that must-have features are included in the final feature set
final_features = list(set(selected_features + must_have_features))
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %%
# Perform cross-validation on the final selected features with scaling in each fold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
f1_scores = []

for train_index, val_index in skf.split(X_train[final_features], y_train):
    X_train_fold, X_val_fold = X_train.iloc[train_index][final_features], X_train.iloc[val_index][final_features]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
    
    # Initialize and fit the scaler only on the training data within each fold to avoid leakage
    scaler = StandardScaler()
    X_train_fold = scaler.fit_transform(X_train_fold)
    X_val_fold = scaler.transform(X_val_fold)
    
    # Train the model
    model.fit(X_train_fold, y_train_fold)
    
    # Make predictions and calculate the F1 score
    y_pred_fold = model.predict(X_val_fold)
    f1 = f1_score(y_val_fold, y_pred_fold, average='macro')
    f1_scores.append(f1)

# Print the results
print(f"Average F1 Score after final evaluation: {np.mean(f1_scores)}")
print("Selected features including must-haves:", final_features)
print("Best F1 macro score from feature selection:", efs.best_score_)
# Out:
#   0%|          | 0/14 [01:50<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[337], line 32
#      28 # Combine the must-have features with other features and scale them in each fold to avoid leakage
#      29 # Track progress with tqdm
#      30 with tqdm(total=len(other_features)) as progress_bar:
#      31     # Fit the feature selector on the dataset that includes both must-have and other features
# ---> 32     efs = efs.fit(X_train[other_features + must_have_features], y_train)
#      33     progress_bar.update(len(other_features))
#      35 # Get the best feature subset found by the selector, which includes combinations of other features and must-have features
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py:443, in ExhaustiveFeatureSelector.fit(self, X, y, groups, **fit_params)
#     440 n_jobs = min(self.n_jobs, all_comb)
#     441 parallel = Parallel(n_jobs=n_jobs, pre_dispatch=self.pre_dispatch)
#     442 work = enumerate(
# --> 443     parallel(
#     444         delayed(_calc_score)(
#     445             self,
#     446             X_,
#     447             y,
#     448             list(set(c).union(self.fixed_features_group_set)),
#     449             groups=groups,
#     450             feature_groups=self.feature_groups,
#     451             **fit_params,
#     452         )
#     453         for c in candidates
#     454     )
#     455 )
#     457 try:
#     458     for iteration, (indices, cv_scores) in work:
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# # VIF

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate VIF for each feature
def calculate_vif(df):
    vif_data = pd.DataFrame()
    vif_data["feature"] = df.columns
    vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif_data

# Calculate VIF for X_train
vif_scores = calculate_vif(X_train)
print(vif_scores)
# Out:
#                       feature       VIF
# 0                         age  1.629907
# 1                alcohol_freq       inf
# 2                caloric_freq       inf
# 3              devices_perday       inf
# 4           eat_between_meals       inf
# 5                      gender  1.979336
# 6                      height  3.566593
# 7                meals_perday  1.107993
# 8            monitor_calories       inf
# 9           parent_overweight  1.449647
# 10  physical_activity_perweek       inf
# 11                   siblings  1.010405
# 12                      smoke       inf
# 13             transportation       inf
# 14               veggies_freq       inf
# 15                water_daily       inf
# 16                     weight  8.128276
# 17                  bmi_class  5.886715
# 18                       life       inf

# %%
best_selected_features_df = X_train[selected_feature_names] # no smoke column

# %% [markdown]
# # Hyperparameter tuning Random Forest

# %%
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit the encoder on y_train and transform y_train
y_train_encoded = label_encoder.fit_transform(y_train)

# Define the objective function for Optuna
def objective(trial):
    # Suggest values for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 100, 500)
    max_depth = trial.suggest_int('max_depth', 5, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    bootstrap = trial.suggest_categorical('bootstrap', [True, False])
    
    # Initialize RandomForestClassifier with suggested hyperparameters
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        bootstrap=bootstrap,
        random_state=42
    )
    
    # Initialize StratifiedKFold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    # Use cross-validation with F1 score for classification
    f1 = cross_val_score(model, best_selected_features_df, y_train_encoded, cv=skf, scoring='f1_macro', n_jobs=-1)
    return f1.mean()

# Set up Optuna study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Retrieve the best parameters
best_params = study.best_params
print("Best Parameters:", best_params)

# Train model with best parameters
best_rf = RandomForestClassifier(**best_params, random_state=42)
best_rf.fit(best_selected_features_df, y_train_encoded)

# Evaluate on training set
print('Train F1 score:', f1_score(y_train_encoded, best_rf.predict(best_selected_features_df), average='macro'))
# Out:
# [I 2024-11-05 16:46:53,247] A new study created in memory with name: no-name-16aa8d07-dc48-45fa-8d6e-e7f4a29e14b7
# [I 2024-11-05 16:47:00,184] Trial 0 finished with value: 0.935580779812474 and parameters: {'n_estimators': 498, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': True}. Best is trial 0 with value: 0.935580779812474.
# [I 2024-11-05 16:47:03,634] Trial 1 finished with value: 0.9437339858520464 and parameters: {'n_estimators': 409, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:05,296] Trial 2 finished with value: 0.9383097297746525 and parameters: {'n_estimators': 437, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:06,317] Trial 3 finished with value: 0.937402914578295 and parameters: {'n_estimators': 233, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:07,681] Trial 4 finished with value: 0.9317857770196334 and parameters: {'n_estimators': 329, 'max_depth': 27, 'min_samples_split': 7, 'min_samples_leaf': 4, 'bootstrap': True}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:08,175] Trial 5 finished with value: 0.9387551152413917 and parameters: {'n_estimators': 119, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:09,774] Trial 6 finished with value: 0.9426091973679573 and parameters: {'n_estimators': 417, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:11,694] Trial 7 finished with value: 0.9311962712734749 and parameters: {'n_estimators': 441, 'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': True}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:13,029] Trial 8 finished with value: 0.9399933567401801 and parameters: {'n_estimators': 348, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:13,802] Trial 9 finished with value: 0.9387533594328854 and parameters: {'n_estimators': 207, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 4, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:14,900] Trial 10 finished with value: 0.9369893765582166 and parameters: {'n_estimators': 284, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 5, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:16,660] Trial 11 finished with value: 0.9401284765007055 and parameters: {'n_estimators': 399, 'max_depth': 21, 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:18,278] Trial 12 finished with value: 0.9424292071786435 and parameters: {'n_estimators': 373, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:20,253] Trial 13 finished with value: 0.9407512354009405 and parameters: {'n_estimators': 489, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:21,889] Trial 14 finished with value: 0.9375009298822269 and parameters: {'n_estimators': 420, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 1 with value: 0.9437339858520464.
# [I 2024-11-05 16:47:23,144] Trial 15 finished with value: 0.9438989112535211 and parameters: {'n_estimators': 303, 'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:24,250] Trial 16 finished with value: 0.9361374334139441 and parameters: {'n_estimators': 280, 'max_depth': 31, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:25,100] Trial 17 finished with value: 0.9424016725649546 and parameters: {'n_estimators': 205, 'max_depth': 24, 'min_samples_split': 6, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:25,759] Trial 18 finished with value: 0.9337922958722679 and parameters: {'n_estimators': 142, 'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 3, 'bootstrap': True}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:27,040] Trial 19 finished with value: 0.9376544670219389 and parameters: {'n_estimators': 318, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 3, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:28,382] Trial 20 finished with value: 0.9368689132798937 and parameters: {'n_estimators': 271, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:29,893] Trial 21 finished with value: 0.9419289554157911 and parameters: {'n_estimators': 380, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:31,748] Trial 22 finished with value: 0.9437477553555269 and parameters: {'n_estimators': 462, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 15 with value: 0.9438989112535211.
# [I 2024-11-05 16:47:33,749] Trial 23 finished with value: 0.9469174624153383 and parameters: {'n_estimators': 470, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:35,733] Trial 24 finished with value: 0.9469174624153383 and parameters: {'n_estimators': 469, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:37,650] Trial 25 finished with value: 0.9424926408682103 and parameters: {'n_estimators': 464, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:39,408] Trial 26 finished with value: 0.9443417041976983 and parameters: {'n_estimators': 356, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:40,934] Trial 27 finished with value: 0.9301039690380408 and parameters: {'n_estimators': 358, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 5, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:43,052] Trial 28 finished with value: 0.94067931830297 and parameters: {'n_estimators': 462, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:45,363] Trial 29 finished with value: 0.9410835421393522 and parameters: {'n_estimators': 495, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:47,828] Trial 30 finished with value: 0.9418330095368315 and parameters: {'n_estimators': 496, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:49,212] Trial 31 finished with value: 0.9443033481214647 and parameters: {'n_estimators': 256, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:50,414] Trial 32 finished with value: 0.9455038205702249 and parameters: {'n_estimators': 241, 'max_depth': 23, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:51,321] Trial 33 finished with value: 0.9380688098844997 and parameters: {'n_estimators': 197, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:52,100] Trial 34 finished with value: 0.9349700943474148 and parameters: {'n_estimators': 173, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:53,229] Trial 35 finished with value: 0.9411889945582981 and parameters: {'n_estimators': 247, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:55,193] Trial 36 finished with value: 0.94067931830297 and parameters: {'n_estimators': 440, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:57,038] Trial 37 finished with value: 0.9443499569449922 and parameters: {'n_estimators': 395, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:47:59,201] Trial 38 finished with value: 0.9400443976680494 and parameters: {'n_estimators': 476, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:01,039] Trial 39 finished with value: 0.9384880222915685 and parameters: {'n_estimators': 397, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:02,976] Trial 40 finished with value: 0.9382590813229793 and parameters: {'n_estimators': 423, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:04,545] Trial 41 finished with value: 0.9430714841234881 and parameters: {'n_estimators': 331, 'max_depth': 17, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:06,188] Trial 42 finished with value: 0.9448864026769123 and parameters: {'n_estimators': 347, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:08,243] Trial 43 finished with value: 0.9418871523628904 and parameters: {'n_estimators': 444, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:09,399] Trial 44 finished with value: 0.9457438084873703 and parameters: {'n_estimators': 231, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:10,404] Trial 45 finished with value: 0.931168708034023 and parameters: {'n_estimators': 218, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:11,122] Trial 46 finished with value: 0.942352163346954 and parameters: {'n_estimators': 166, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:12,200] Trial 47 finished with value: 0.9400900389087916 and parameters: {'n_estimators': 234, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:13,287] Trial 48 finished with value: 0.9455692743955024 and parameters: {'n_estimators': 263, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 1, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# [I 2024-11-05 16:48:14,326] Trial 49 finished with value: 0.9431800263174329 and parameters: {'n_estimators': 254, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 23 with value: 0.9469174624153383.
# Best Parameters: {'n_estimators': 470, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 1, 'bootstrap': False}
# Train F1 score: 0.9993578286816801

# %% [markdown]
# # Hyperparameter tuning GBC

# %%
import optuna
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit the encoder on y_train and transform y_train
y_train_encoded = label_encoder.fit_transform(y_train)

# Define the objective function for Optuna
def objective(trial):
    # Suggest values for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 100, 500)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    subsample = trial.suggest_float('subsample', 0.5, 1.0)
    
    # Initialize GradientBoostingClassifier with suggested hyperparameters
    model = GradientBoostingClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        subsample=subsample,
        random_state=42
    )
    
    # Initialize StratifiedKFold
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    # Use cross-validation with F1 score for classification
    f1 = cross_val_score(model, best_selected_features_df, y_train_encoded, cv=skf, scoring='f1_macro', n_jobs=-1)
    return f1.mean()

# Set up Optuna study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Retrieve the best parameters
best_params = study.best_params
print("Best Parameters:", best_params)

# Train model with best parameters
best_gb = GradientBoostingClassifier(**best_params, random_state=42)
best_gb.fit(best_selected_features_df, y_train_encoded)

# Evaluate on training set
print('Train F1 score:', f1_score(y_train_encoded, best_gb.predict(best_selected_features_df), average='macro'))
# Out:
# [I 2024-11-05 20:33:01,551] A new study created in memory with name: no-name-31cefac8-9da3-4c0d-832a-e2e1b1afa7be
# [I 2024-11-05 20:33:13,653] Trial 0 finished with value: 0.9404468929725944 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.05683514780729142, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.9953730884345451}. Best is trial 0 with value: 0.9404468929725944.
# [I 2024-11-05 20:33:31,696] Trial 1 finished with value: 0.9503314554079815 and parameters: {'n_estimators': 385, 'max_depth': 6, 'learning_rate': 0.08965329806897641, 'min_samples_split': 6, 'min_samples_leaf': 3, 'subsample': 0.9930683042967535}. Best is trial 1 with value: 0.9503314554079815.
# [I 2024-11-05 20:33:53,122] Trial 2 finished with value: 0.9494761194976329 and parameters: {'n_estimators': 358, 'max_depth': 9, 'learning_rate': 0.0990952271899798, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.6025110263081686}. Best is trial 1 with value: 0.9503314554079815.
# [I 2024-11-05 20:34:08,612] Trial 3 finished with value: 0.9548502430826019 and parameters: {'n_estimators': 381, 'max_depth': 6, 'learning_rate': 0.10541712456679432, 'min_samples_split': 5, 'min_samples_leaf': 5, 'subsample': 0.5729735978411137}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:34:27,601] Trial 4 finished with value: 0.9513742998713088 and parameters: {'n_estimators': 427, 'max_depth': 9, 'learning_rate': 0.10180181339609118, 'min_samples_split': 9, 'min_samples_leaf': 5, 'subsample': 0.9548532848727344}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:34:34,363] Trial 5 finished with value: 0.9545269045469669 and parameters: {'n_estimators': 136, 'max_depth': 8, 'learning_rate': 0.26173327054970924, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.7401387823156388}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:34:44,205] Trial 6 finished with value: 0.9539168634314541 and parameters: {'n_estimators': 346, 'max_depth': 4, 'learning_rate': 0.07860433478853075, 'min_samples_split': 7, 'min_samples_leaf': 5, 'subsample': 0.5244383416218417}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:34:53,170] Trial 7 finished with value: 0.9344485520116759 and parameters: {'n_estimators': 392, 'max_depth': 3, 'learning_rate': 0.22065405752941636, 'min_samples_split': 9, 'min_samples_leaf': 4, 'subsample': 0.682911282835998}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:35:00,738] Trial 8 finished with value: 0.948968842351898 and parameters: {'n_estimators': 118, 'max_depth': 8, 'learning_rate': 0.17820557356858657, 'min_samples_split': 8, 'min_samples_leaf': 2, 'subsample': 0.553488893860631}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:35:18,359] Trial 9 finished with value: 0.9545792843888992 and parameters: {'n_estimators': 349, 'max_depth': 7, 'learning_rate': 0.10061283756870601, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.5675971174964392}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:35:53,207] Trial 10 finished with value: 0.9473365952887237 and parameters: {'n_estimators': 488, 'max_depth': 6, 'learning_rate': 0.01738705238059836, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.8501601571907236}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:36:05,052] Trial 11 finished with value: 0.9543730172578975 and parameters: {'n_estimators': 268, 'max_depth': 7, 'learning_rate': 0.14745926086694455, 'min_samples_split': 5, 'min_samples_leaf': 4, 'subsample': 0.6241722943411515}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:36:14,474] Trial 12 finished with value: 0.9527507362733724 and parameters: {'n_estimators': 270, 'max_depth': 5, 'learning_rate': 0.15572956966917484, 'min_samples_split': 6, 'min_samples_leaf': 2, 'subsample': 0.5107435387015833}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:36:44,059] Trial 13 finished with value: 0.9494833355094636 and parameters: {'n_estimators': 464, 'max_depth': 7, 'learning_rate': 0.013093826287726956, 'min_samples_split': 4, 'min_samples_leaf': 5, 'subsample': 0.6684326492904815}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:37:00,808] Trial 14 finished with value: 0.9505196505417285 and parameters: {'n_estimators': 317, 'max_depth': 10, 'learning_rate': 0.12689296671007294, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.7999651592562387}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:37:10,014] Trial 15 finished with value: 0.9505902413427068 and parameters: {'n_estimators': 226, 'max_depth': 5, 'learning_rate': 0.05208309610179384, 'min_samples_split': 4, 'min_samples_leaf': 4, 'subsample': 0.5807630534854248}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:37:21,193] Trial 16 finished with value: 0.9545486978673601 and parameters: {'n_estimators': 437, 'max_depth': 5, 'learning_rate': 0.194813406698743, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.6881524535201173}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:37:35,800] Trial 17 finished with value: 0.9508266575713581 and parameters: {'n_estimators': 308, 'max_depth': 8, 'learning_rate': 0.1293324859801981, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.6319105725200024}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:37:44,575] Trial 18 finished with value: 0.9520969631170939 and parameters: {'n_estimators': 416, 'max_depth': 6, 'learning_rate': 0.28016610509090606, 'min_samples_split': 10, 'min_samples_leaf': 4, 'subsample': 0.7436898849131843}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:38:11,757] Trial 19 finished with value: 0.9474442154194502 and parameters: {'n_estimators': 359, 'max_depth': 7, 'learning_rate': 0.03981175456979563, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.8708231127331655}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:38:25,167] Trial 20 finished with value: 0.9443081238223353 and parameters: {'n_estimators': 500, 'max_depth': 10, 'learning_rate': 0.22923775136112218, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.5637902023816029}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:38:35,758] Trial 21 finished with value: 0.9520345347726835 and parameters: {'n_estimators': 442, 'max_depth': 5, 'learning_rate': 0.1935045034486944, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.695765036532923}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:38:46,258] Trial 22 finished with value: 0.9524991104681202 and parameters: {'n_estimators': 400, 'max_depth': 4, 'learning_rate': 0.18526516740107335, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.654584925084667}. Best is trial 3 with value: 0.9548502430826019.
# [I 2024-11-05 20:39:00,453] Trial 23 finished with value: 0.9550910326664457 and parameters: {'n_estimators': 448, 'max_depth': 5, 'learning_rate': 0.11803400738569385, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.7089298889017902}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:39:14,362] Trial 24 finished with value: 0.9527194377133796 and parameters: {'n_estimators': 330, 'max_depth': 6, 'learning_rate': 0.1191821932247966, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.5020614050173141}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:39:21,523] Trial 25 finished with value: 0.9473457631015748 and parameters: {'n_estimators': 279, 'max_depth': 3, 'learning_rate': 0.07332917043860573, 'min_samples_split': 6, 'min_samples_leaf': 3, 'subsample': 0.7935321111238163}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:39:38,431] Trial 26 finished with value: 0.9517613108550382 and parameters: {'n_estimators': 467, 'max_depth': 7, 'learning_rate': 0.11131888249628895, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.5915213742336539}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:39:50,647] Trial 27 finished with value: 0.953221047064978 and parameters: {'n_estimators': 373, 'max_depth': 6, 'learning_rate': 0.13977134143989572, 'min_samples_split': 6, 'min_samples_leaf': 2, 'subsample': 0.7137404011505079}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:40:07,110] Trial 28 finished with value: 0.954391130809858 and parameters: {'n_estimators': 460, 'max_depth': 5, 'learning_rate': 0.06825283088748427, 'min_samples_split': 5, 'min_samples_leaf': 4, 'subsample': 0.5431692243420045}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:40:14,144] Trial 29 finished with value: 0.9498442952512797 and parameters: {'n_estimators': 229, 'max_depth': 4, 'learning_rate': 0.1595591632401377, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.631691584593943}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:40:47,411] Trial 30 finished with value: 0.9488226726042397 and parameters: {'n_estimators': 409, 'max_depth': 8, 'learning_rate': 0.04387751933325017, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.83750838855912}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:40:58,334] Trial 31 finished with value: 0.9494775060040943 and parameters: {'n_estimators': 431, 'max_depth': 5, 'learning_rate': 0.21944775052011772, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.719960507747057}. Best is trial 23 with value: 0.9550910326664457.
# [I 2024-11-05 20:41:14,347] Trial 32 finished with value: 0.9551599332169382 and parameters: {'n_estimators': 381, 'max_depth': 5, 'learning_rate': 0.08465206461732597, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.773170600903127}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:41:30,973] Trial 33 finished with value: 0.9495259881732304 and parameters: {'n_estimators': 342, 'max_depth': 6, 'learning_rate': 0.08801600823362142, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.9277729016338377}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:41:43,280] Trial 34 finished with value: 0.9533288509678558 and parameters: {'n_estimators': 379, 'max_depth': 4, 'learning_rate': 0.10513509764550956, 'min_samples_split': 6, 'min_samples_leaf': 2, 'subsample': 0.7751413835308819}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:41:59,787] Trial 35 finished with value: 0.9549808673790625 and parameters: {'n_estimators': 368, 'max_depth': 6, 'learning_rate': 0.09060283279542514, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.7675664493237456}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:42:21,048] Trial 36 finished with value: 0.9550880417279055 and parameters: {'n_estimators': 376, 'max_depth': 6, 'learning_rate': 0.06176770151540724, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.7641839087105581}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:42:37,573] Trial 37 finished with value: 0.9481357825900835 and parameters: {'n_estimators': 367, 'max_depth': 5, 'learning_rate': 0.028799465377297433, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.7640078330373673}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:43:00,154] Trial 38 finished with value: 0.9545517302659146 and parameters: {'n_estimators': 396, 'max_depth': 6, 'learning_rate': 0.060752102721829966, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.8208931513641453}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:43:11,655] Trial 39 finished with value: 0.9506626158047009 and parameters: {'n_estimators': 323, 'max_depth': 4, 'learning_rate': 0.08687249384122102, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.9152301130930819}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:43:19,004] Trial 40 finished with value: 0.9473982134824782 and parameters: {'n_estimators': 293, 'max_depth': 3, 'learning_rate': 0.07922664149423696, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.7350219547769417}. Best is trial 32 with value: 0.9551599332169382.
# [I 2024-11-05 20:43:35,284] Trial 41 finished with value: 0.957615833801019 and parameters: {'n_estimators': 417, 'max_depth': 6, 'learning_rate': 0.09668948505199103, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.7790815568978012}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:43:52,404] Trial 42 finished with value: 0.9547945031798551 and parameters: {'n_estimators': 415, 'max_depth': 6, 'learning_rate': 0.09159115983550323, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.7800761180711675}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:44:12,319] Trial 43 finished with value: 0.9526199128742092 and parameters: {'n_estimators': 451, 'max_depth': 5, 'learning_rate': 0.05306112096203404, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.8068355045906387}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:44:27,239] Trial 44 finished with value: 0.9506162714330305 and parameters: {'n_estimators': 478, 'max_depth': 6, 'learning_rate': 0.11173583261014787, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.8661269221939385}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:44:38,830] Trial 45 finished with value: 0.9481828821714215 and parameters: {'n_estimators': 161, 'max_depth': 7, 'learning_rate': 0.0649399050656096, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.7548505161157989}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:44:50,830] Trial 46 finished with value: 0.9540273641557574 and parameters: {'n_estimators': 392, 'max_depth': 5, 'learning_rate': 0.1369565254716201, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.7259696990266054}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:45:06,837] Trial 47 finished with value: 0.9546631505488721 and parameters: {'n_estimators': 420, 'max_depth': 6, 'learning_rate': 0.09561870444419011, 'min_samples_split': 4, 'min_samples_leaf': 1, 'subsample': 0.8278100599297846}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:45:30,793] Trial 48 finished with value: 0.9255383681983105 and parameters: {'n_estimators': 345, 'max_depth': 7, 'learning_rate': 0.0013224580524481971, 'min_samples_split': 4, 'min_samples_leaf': 4, 'subsample': 0.6993086312824299}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:45:44,602] Trial 49 finished with value: 0.9467616715441235 and parameters: {'n_estimators': 386, 'max_depth': 9, 'learning_rate': 0.16216411906528572, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.7653585255123169}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:46:01,240] Trial 50 finished with value: 0.9488881462264087 and parameters: {'n_estimators': 361, 'max_depth': 5, 'learning_rate': 0.03700992653383697, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.7890491485126055}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:46:18,639] Trial 51 finished with value: 0.9574928172249081 and parameters: {'n_estimators': 379, 'max_depth': 6, 'learning_rate': 0.07875493390327225, 'min_samples_split': 6, 'min_samples_leaf': 5, 'subsample': 0.6570952911886422}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:46:38,709] Trial 52 finished with value: 0.9564051776953019 and parameters: {'n_estimators': 437, 'max_depth': 6, 'learning_rate': 0.07753379592862769, 'min_samples_split': 8, 'min_samples_leaf': 4, 'subsample': 0.6492546693500093}. Best is trial 41 with value: 0.957615833801019.
# [I 2024-11-05 20:47:00,401] Trial 53 finished with value: 0.9570050267147872 and parameters: {'n_estimators': 444, 'max_depth': 7, 'learning_rate': 0.07812502427378391, 'min_samples_split': 10, 'min_samples_leaf': 5, 'subsample': 0.6584972429810468}. Best is trial 41 with value: 0.957615833801019.
# [W 2024-11-05 20:47:07,069] Trial 54 failed with parameters: {'n_estimators': 439, 'max_depth': 7, 'learning_rate': 0.07893355901386286, 'min_samples_split': 10, 'min_samples_leaf': 5, 'subsample': 0.662834799872168} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\wojci\AppData\Local\Temp\ipykernel_22564\3147898763.py", line 38, in objective
#     f1 = cross_val_score(model, best_selected_features_df, y_train_encoded, cv=skf, scoring='f1_macro', n_jobs=-1)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\model_selection\_validation.py", line 712, in cross_val_score
#     cv_results = cross_validate(
#                  ^^^^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\model_selection\_validation.py", line 423, in cross_validate
#     results = parallel(
#               ^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\parallel.py", line 74, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2024-11-05 20:47:07,072] Trial 54 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[291], line 43
#      41 # Set up Optuna study and optimize
#      42 study = optuna.create_study(direction='maximize')
# ---> 43 study.optimize(objective, n_trials=100)
#      45 # Retrieve the best parameters
#      46 best_params = study.best_params
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[291], line 38, in objective(trial)
#      35 skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
#      37 # Use cross-validation with F1 score for classification
# ---> 38 f1 = cross_val_score(model, best_selected_features_df, y_train_encoded, cv=skf, scoring='f1_macro', n_jobs=-1)
#      39 return f1.mean()
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\model_selection\_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\model_selection\_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\wojci\anaconda3\envs\Machine-Learning\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# <a class="anchor" id="">
#
# # 4 & 5. Model & Assess (Modelling and Assessment)
#
# </a>

# %% [markdown]
# <img src="image/step4.png" style="height:60px">

# %% [markdown]
# ### 4.1. Model Selection
#
# In this section you should take the time to train different predictive algorithms with the data that got to this stage and **use the approppriate model assessment metrics to decide which model you think is the best to address your problem**.
#
# **You are expected to present on your report the model performances of the different algorithms that you tested and discuss what informed your choice for a specific algorithm**

# %% [markdown]
# ### 4.2. Model Optimization
#
# After selecting the best algorithm (set of algorithms), you can try to optimize the performance of your model by fiddling with the algorithms' hyper-parameters and select the options that result on the best overall performance.
#
# Possible ways of doing this can be through:
# 1. [GridSearch](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# 2. [RandomSearch](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# **While you are not required to show the results of all combinations of hyperparameters that you tried, you should at least discuss the what were the possible combinations used and which of them resulted in your best performance**

# %% [markdown]
# <a class="anchor" id="">
#
# # 5. Deploy
#
# </a>

# %% [markdown]
# <img src="image/step5.png" style="height:60px">
#
# ### 5.0 Training a final model
#
# You used the previous steps of modelling and assessment to determine what would be best strategies when it comes to preprocessing, scaling, feature selection, algorithm and hyper-parameters you could find.
#
# **By this stage, all of those choices were already made**. For that reason, a split between training and validation is no longer necessary. **A good practice** would be to take the initial data and train a final model with all of the labeled data that you have available.
#
# **Everything is figured by this stage**, so, on a first level all you need to do is replicate the exact preprocessing, scaling and feature selection decisions you made before.<br>
# When it comes to the final model, all you have to do is creeate a new instance of your best algorithm with the best parameters that you uncovered (no need to try all algorithms and hyper-parameters again).

# %% [markdown]
# ### 5.1. Import and Transform your test data
#
# Remember, the test data does not have the `outcome` variable.

# %% [markdown]
# ### 5.2. Obtain Predictions on the test data from your final model

# %% [markdown]
# ### 5.3. Create a Dataframe containing the index of each row and its intended prediction and export it to a csv file

# %% [markdown]
# Submit the csv file to Kaggle to obtain the model performance of your model on the test data.
