# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder, StandardScaler, RobustScaler, MinMaxScaler
from sklearn.impute import SimpleImputer, KNNImputer

# %%
# Load the data
obesity_train_raw = pd.read_csv('data/obesity_train.csv')
obesity_test_raw = pd.read_csv('data/obesity_test.csv')

# %%
obesity_train_raw
# Out:
#         id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0        1  21.0        Never           no        up to 5         Sometimes
# 1        2  23.0   Frequently           no        up to 5         Sometimes
# 2        3   NaN   Frequently           no        up to 2         Sometimes
# 3        4  22.0    Sometimes           no        up to 2         Sometimes
# 4        5  22.0    Sometimes           no        up to 2         Sometimes
# ...    ...   ...          ...          ...            ...               ...
# 1606  1607  21.0    Sometimes          NaN        up to 5         Sometimes
# 1607  1608  22.0    Sometimes          yes        up to 5         Sometimes
# 1608  1609  23.0    Sometimes          yes        up to 5         Sometimes
# 1609  1610  24.0    Sometimes          yes        up to 5         Sometimes
# 1610  1611  24.0    Sometimes          yes        up to 5         Sometimes
#
#       gender  height  marrital_status  meals_perday  ... parent_overweight  \
# 0     Female    1.62              NaN           3.0  ...               yes
# 1       Male    1.80              NaN           3.0  ...               yes
# 2       Male    1.80              NaN           3.0  ...                no
# 3       Male    1.78              NaN           1.0  ...                no
# 4       Male    1.64              NaN           3.0  ...                no
# ...      ...     ...              ...           ...  ...               ...
# 1606  Female    1.73              NaN           3.0  ...               yes
# 1607  Female    1.75              NaN           3.0  ...               yes
# 1608  Female    1.75              NaN           3.0  ...               yes
# 1609  Female    1.74              NaN           3.0  ...               yes
# 1610  Female    1.74              NaN           3.0  ...               yes
#
#      physical_activity_perweek region siblings  smoke transportation  \
# 0                          NaN  LatAm      3.0     no         Public
# 1                       3 to 4  LatAm      0.0     no         Public
# 2                       3 to 4  LatAm      2.0     no           Walk
# 3                          NaN  LatAm      3.0     no         Public
# 4                    5 or more  LatAm      3.0     no         Public
# ...                        ...    ...      ...    ...            ...
# 1606                    3 to 4  LatAm      1.0     no         Public
# 1607                    1 to 2  LatAm      0.0     no            NaN
# 1608                    1 to 2  LatAm      0.0     no         Public
# 1609                    1 to 2  LatAm      0.0     no         Public
# 1610                    1 to 2  LatAm      0.0     no         Public
#
#      veggies_freq  water_daily weight          obese_level
# 0       Sometimes       1 to 2   64.0        Normal_Weight
# 1       Sometimes       1 to 2   77.0        Normal_Weight
# 2          Always       1 to 2   87.0   Overweight_Level_I
# 3       Sometimes       1 to 2   90.0  Overweight_Level_II
# 4       Sometimes       1 to 2   53.0        Normal_Weight
# ...           ...          ...    ...                  ...
# 1606       Always       1 to 2  131.0     Obesity_Type_III
# 1607       Always       1 to 2  134.0     Obesity_Type_III
# 1608       Always       1 to 2  134.0     Obesity_Type_III
# 1609       Always  more than 2  133.0     Obesity_Type_III
# 1610       Always  more than 2  133.0     Obesity_Type_III
#
# [1611 rows x 21 columns]

# %%
# Drop the 'marrital_status' and 'region' columns from the dataset
obesity_train = obesity_train_raw.drop(columns=['marrital_status', 'region'])
obesity_test = obesity_test_raw.drop(columns=['marrital_status', 'region'])

# %%
obesity_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1545 non-null   float64
#  2   alcohol_freq               1575 non-null   object
#  3   caloric_freq               1591 non-null   object
#  4   devices_perday             1589 non-null   object
#  5   eat_between_meals          1552 non-null   object
#  6   gender                     1591 non-null   object
#  7   height                     1597 non-null   float64
#  8   meals_perday               1602 non-null   float64
#  9   monitor_calories           1572 non-null   object
#  10  parent_overweight          1591 non-null   object
#  11  physical_activity_perweek  1046 non-null   object
#  12  siblings                   1599 non-null   float64
#  13  smoke                      1599 non-null   object
#  14  transportation             1571 non-null   object
#  15  veggies_freq               1585 non-null   object
#  16  water_daily                1577 non-null   object
#  17  weight                     1558 non-null   float64
#  18  obese_level                1611 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 239.3+ KB

# %%
dummy_columns = ['alcohol_freq','caloric_freq','devices_perday','eat_between_meals','gender',
                 'monitor_calories','parent_overweight','physical_activity_perweek','smoke','transportation',
                 'veggies_freq','water_daily']
numeric_columns = ['age','height','meals_perday','weight','siblings']

# %%
obesity_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1545 non-null   float64
#  2   alcohol_freq               1575 non-null   object
#  3   caloric_freq               1591 non-null   object
#  4   devices_perday             1589 non-null   object
#  5   eat_between_meals          1552 non-null   object
#  6   gender                     1591 non-null   object
#  7   height                     1597 non-null   float64
#  8   meals_perday               1602 non-null   float64
#  9   monitor_calories           1572 non-null   object
#  10  parent_overweight          1591 non-null   object
#  11  physical_activity_perweek  1046 non-null   object
#  12  siblings                   1599 non-null   float64
#  13  smoke                      1599 non-null   object
#  14  transportation             1571 non-null   object
#  15  veggies_freq               1585 non-null   object
#  16  water_daily                1577 non-null   object
#  17  weight                     1558 non-null   float64
#  18  obese_level                1611 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 239.3+ KB

# %%
def imputer(data_train, data_val, columns, strategy):
    """
    """
    # Impute 
    imputer = SimpleImputer(strategy=strategy)
    for column in columns:
        imputer = imputer.fit(data_train[[column]])
        data_train[[column]] = imputer.transform(data_train[[column]])
        data_val[[column]] = imputer.transform(data_val[[column]])
    
    return data_train, data_val

# %%
obesity_train_imp, obesity_test_imp = imputer(obesity_train, obesity_test, dummy_columns, strategy='most_frequent')
obesity_train_imp, obesity_test_imp = imputer(obesity_train, obesity_test, numeric_columns, strategy='median')

# %%
obesity_train_imp.info()
obesity_train_imp
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1611 non-null   float64
#  2   alcohol_freq               1611 non-null   object
#  3   caloric_freq               1611 non-null   object
#  4   devices_perday             1611 non-null   object
#  5   eat_between_meals          1611 non-null   object
#  6   gender                     1611 non-null   object
#  7   height                     1611 non-null   float64
#  8   meals_perday               1611 non-null   float64
#  9   monitor_calories           1611 non-null   object
#  10  parent_overweight          1611 non-null   object
#  11  physical_activity_perweek  1611 non-null   object
#  12  siblings                   1611 non-null   float64
#  13  smoke                      1611 non-null   object
#  14  transportation             1611 non-null   object
#  15  veggies_freq               1611 non-null   object
#  16  water_daily                1611 non-null   object
#  17  weight                     1611 non-null   float64
#  18  obese_level                1611 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 239.3+ KB
#         id   age alcohol_freq caloric_freq devices_perday eat_between_meals  \
# 0        1  21.0        Never           no        up to 5         Sometimes
# 1        2  23.0   Frequently           no        up to 5         Sometimes
# 2        3  23.0   Frequently           no        up to 2         Sometimes
# 3        4  22.0    Sometimes           no        up to 2         Sometimes
# 4        5  22.0    Sometimes           no        up to 2         Sometimes
# ...    ...   ...          ...          ...            ...               ...
# 1606  1607  21.0    Sometimes          yes        up to 5         Sometimes
# 1607  1608  22.0    Sometimes          yes        up to 5         Sometimes
# 1608  1609  23.0    Sometimes          yes        up to 5         Sometimes
# 1609  1610  24.0    Sometimes          yes        up to 5         Sometimes
# 1610  1611  24.0    Sometimes          yes        up to 5         Sometimes
#
#       gender  height  meals_perday monitor_calories parent_overweight  \
# 0     Female    1.62           3.0               no               yes
# 1       Male    1.80           3.0               no               yes
# 2       Male    1.80           3.0               no                no
# 3       Male    1.78           1.0               no                no
# 4       Male    1.64           3.0               no                no
# ...      ...     ...           ...              ...               ...
# 1606  Female    1.73           3.0               no               yes
# 1607  Female    1.75           3.0               no               yes
# 1608  Female    1.75           3.0               no               yes
# 1609  Female    1.74           3.0               no               yes
# 1610  Female    1.74           3.0               no               yes
#
#      physical_activity_perweek  siblings smoke transportation veggies_freq  \
# 0                       1 to 2       3.0    no         Public    Sometimes
# 1                       3 to 4       0.0    no         Public    Sometimes
# 2                       3 to 4       2.0    no           Walk       Always
# 3                       1 to 2       3.0    no         Public    Sometimes
# 4                    5 or more       3.0    no         Public    Sometimes
# ...                        ...       ...   ...            ...          ...
# 1606                    3 to 4       1.0    no         Public       Always
# 1607                    1 to 2       0.0    no         Public       Always
# 1608                    1 to 2       0.0    no         Public       Always
# 1609                    1 to 2       0.0    no         Public       Always
# 1610                    1 to 2       0.0    no         Public       Always
#
#       water_daily  weight          obese_level
# 0          1 to 2    64.0        Normal_Weight
# 1          1 to 2    77.0        Normal_Weight
# 2          1 to 2    87.0   Overweight_Level_I
# 3          1 to 2    90.0  Overweight_Level_II
# 4          1 to 2    53.0        Normal_Weight
# ...           ...     ...                  ...
# 1606       1 to 2   131.0     Obesity_Type_III
# 1607       1 to 2   134.0     Obesity_Type_III
# 1608       1 to 2   134.0     Obesity_Type_III
# 1609  more than 2   133.0     Obesity_Type_III
# 1610  more than 2   133.0     Obesity_Type_III
#
# [1611 rows x 19 columns]

# %%
obesity_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1611 non-null   int64
#  1   age                        1545 non-null   float64
#  2   alcohol_freq               1575 non-null   object
#  3   caloric_freq               1591 non-null   object
#  4   devices_perday             1589 non-null   object
#  5   eat_between_meals          1552 non-null   object
#  6   gender                     1591 non-null   object
#  7   height                     1597 non-null   float64
#  8   meals_perday               1602 non-null   float64
#  9   monitor_calories           1572 non-null   object
#  10  parent_overweight          1591 non-null   object
#  11  physical_activity_perweek  1046 non-null   object
#  12  siblings                   1599 non-null   float64
#  13  smoke                      1599 non-null   object
#  14  transportation             1571 non-null   object
#  15  veggies_freq               1585 non-null   object
#  16  water_daily                1577 non-null   object
#  17  weight                     1558 non-null   float64
#  18  obese_level                1611 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 239.3+ KB

# %%
obesity_train.drop(columns=['obese_level'], inplace=True)

# %%
obesity_train_label_enc = obesity_train.copy()

for column in dummy_columns:
    le = OrdinalEncoder(encoded_missing_value=np.nan)
    obesity_train_label_enc[[column]] = le.fit_transform(obesity_train_label_enc[[column]])

obesity_train_label_enc
# Out:
#         id   age  alcohol_freq  caloric_freq  devices_perday  \
# 0        1  21.0           2.0           0.0             2.0
# 1        2  23.0           1.0           0.0             2.0
# 2        3   NaN           1.0           0.0             1.0
# 3        4  22.0           3.0           0.0             1.0
# 4        5  22.0           3.0           0.0             1.0
# ...    ...   ...           ...           ...             ...
# 1606  1607  21.0           3.0           NaN             2.0
# 1607  1608  22.0           3.0           1.0             2.0
# 1608  1609  23.0           3.0           1.0             2.0
# 1609  1610  24.0           3.0           1.0             2.0
# 1610  1611  24.0           3.0           1.0             2.0
#
#       eat_between_meals  gender  height  meals_perday  monitor_calories  \
# 0                   3.0     0.0    1.62           3.0               0.0
# 1                   3.0     1.0    1.80           3.0               0.0
# 2                   3.0     1.0    1.80           3.0               0.0
# 3                   3.0     1.0    1.78           1.0               0.0
# 4                   3.0     1.0    1.64           3.0               0.0
# ...                 ...     ...     ...           ...               ...
# 1606                3.0     0.0    1.73           3.0               0.0
# 1607                3.0     0.0    1.75           3.0               0.0
# 1608                3.0     0.0    1.75           3.0               0.0
# 1609                3.0     0.0    1.74           3.0               0.0
# 1610                3.0     0.0    1.74           3.0               0.0
#
#       parent_overweight  physical_activity_perweek  siblings  smoke  \
# 0                   1.0                        NaN       3.0    0.0
# 1                   1.0                        1.0       0.0    0.0
# 2                   0.0                        1.0       2.0    0.0
# 3                   0.0                        NaN       3.0    0.0
# 4                   0.0                        2.0       3.0    0.0
# ...                 ...                        ...       ...    ...
# 1606                1.0                        1.0       1.0    0.0
# 1607                1.0                        0.0       0.0    0.0
# 1608                1.0                        0.0       0.0    0.0
# 1609                1.0                        0.0       0.0    0.0
# 1610                1.0                        0.0       0.0    0.0
#
#       transportation  veggies_freq  water_daily  weight
# 0                3.0           2.0          0.0    64.0
# 1                3.0           2.0          0.0    77.0
# 2                4.0           0.0          0.0    87.0
# 3                3.0           2.0          0.0    90.0
# 4                3.0           2.0          0.0    53.0
# ...              ...           ...          ...     ...
# 1606             3.0           0.0          0.0   131.0
# 1607             NaN           0.0          0.0   134.0
# 1608             3.0           0.0          0.0   134.0
# 1609             3.0           0.0          2.0   133.0
# 1610             3.0           0.0          2.0   133.0
#
# [1611 rows x 18 columns]

# %%
# Apply KNN imputer
knn_imputer = KNNImputer(n_neighbors=5)
obesity_train_label_enc_imputed = pd.DataFrame(knn_imputer.fit_transform(obesity_train_label_enc), columns=obesity_train_label_enc.columns)

obesity_train_label_enc_imputed
# Out:
#           id   age  alcohol_freq  caloric_freq  devices_perday  \
# 0        1.0  21.0           2.0           0.0             2.0
# 1        2.0  23.0           1.0           0.0             2.0
# 2        3.0  28.0           1.0           0.0             1.0
# 3        4.0  22.0           3.0           0.0             1.0
# 4        5.0  22.0           3.0           0.0             1.0
# ...      ...   ...           ...           ...             ...
# 1606  1607.0  21.0           3.0           1.0             2.0
# 1607  1608.0  22.0           3.0           1.0             2.0
# 1608  1609.0  23.0           3.0           1.0             2.0
# 1609  1610.0  24.0           3.0           1.0             2.0
# 1610  1611.0  24.0           3.0           1.0             2.0
#
#       eat_between_meals  gender  height  meals_perday  monitor_calories  \
# 0                   3.0     0.0    1.62           3.0               0.0
# 1                   3.0     1.0    1.80           3.0               0.0
# 2                   3.0     1.0    1.80           3.0               0.0
# 3                   3.0     1.0    1.78           1.0               0.0
# 4                   3.0     1.0    1.64           3.0               0.0
# ...                 ...     ...     ...           ...               ...
# 1606                3.0     0.0    1.73           3.0               0.0
# 1607                3.0     0.0    1.75           3.0               0.0
# 1608                3.0     0.0    1.75           3.0               0.0
# 1609                3.0     0.0    1.74           3.0               0.0
# 1610                3.0     0.0    1.74           3.0               0.0
#
#       parent_overweight  physical_activity_perweek  siblings  smoke  \
# 0                   1.0                        0.8       3.0    0.0
# 1                   1.0                        1.0       0.0    0.0
# 2                   0.0                        1.0       2.0    0.0
# 3                   0.0                        1.0       3.0    0.0
# 4                   0.0                        2.0       3.0    0.0
# ...                 ...                        ...       ...    ...
# 1606                1.0                        1.0       1.0    0.0
# 1607                1.0                        0.0       0.0    0.0
# 1608                1.0                        0.0       0.0    0.0
# 1609                1.0                        0.0       0.0    0.0
# 1610                1.0                        0.0       0.0    0.0
#
#       transportation  veggies_freq  water_daily  weight
# 0                3.0           2.0          0.0    64.0
# 1                3.0           2.0          0.0    77.0
# 2                4.0           0.0          0.0    87.0
# 3                3.0           2.0          0.0    90.0
# 4                3.0           2.0          0.0    53.0
# ...              ...           ...          ...     ...
# 1606             3.0           0.0          0.0   131.0
# 1607             3.0           0.0          0.0   134.0
# 1608             3.0           0.0          0.0   134.0
# 1609             3.0           0.0          2.0   133.0
# 1610             3.0           0.0          2.0   133.0
#
# [1611 rows x 18 columns]

# %%
# Inverse transform to original labels
for column in dummy_columns:
    le = OrdinalEncoder(encoded_missing_value=np.nan)
    obesity_train_label_enc_imputed[[column]] = le.fit(obesity_train[[column]]).inverse_transform(obesity_train_label_enc_imputed[[column]])

# %%
obesity_train_label_enc_imputed
# Out:
#      alcohol_freq caloric_freq devices_perday eat_between_meals  gender  \
# 0           Never           no        up to 5         Sometimes  Female
# 1      Frequently           no        up to 5         Sometimes    Male
# 2      Frequently           no        up to 2         Sometimes    Male
# 3       Sometimes           no        up to 2         Sometimes    Male
# 4       Sometimes           no        up to 2         Sometimes    Male
# ...           ...          ...            ...               ...     ...
# 1606    Sometimes          yes        up to 5         Sometimes  Female
# 1607    Sometimes          yes        up to 5         Sometimes  Female
# 1608    Sometimes          yes        up to 5         Sometimes  Female
# 1609    Sometimes          yes        up to 5         Sometimes  Female
# 1610    Sometimes          yes        up to 5         Sometimes  Female
#
#      monitor_calories parent_overweight physical_activity_perweek smoke  \
# 0                  no               yes                    1 to 2    no
# 1                  no               yes                    3 to 4    no
# 2                  no                no                    3 to 4    no
# 3                  no                no                    1 to 2    no
# 4                  no                no                 5 or more    no
# ...               ...               ...                       ...   ...
# 1606               no               yes                    3 to 4    no
# 1607               no               yes                    1 to 2    no
# 1608               no               yes                    1 to 2    no
# 1609               no               yes                    1 to 2    no
# 1610               no               yes                    1 to 2    no
#
#      transportation veggies_freq  water_daily
# 0            Public    Sometimes       1 to 2
# 1            Public    Sometimes       1 to 2
# 2              Walk       Always       1 to 2
# 3            Public    Sometimes       1 to 2
# 4            Public    Sometimes       1 to 2
# ...             ...          ...          ...
# 1606         Public       Always       1 to 2
# 1607         Public       Always       1 to 2
# 1608         Public       Always       1 to 2
# 1609         Public       Always  more than 2
# 1610         Public       Always  more than 2
#
# [1611 rows x 12 columns]

# %%
x=pd.get_dummies(obesity_train[dummy_columns],dummy_na=True, drop_first=True)
print(x.info())
x
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   alcohol_freq_Frequently              1611 non-null   bool
#  1   alcohol_freq_Never                   1611 non-null   bool
#  2   alcohol_freq_Sometimes               1611 non-null   bool
#  3   alcohol_freq_nan                     1611 non-null   bool
#  4   caloric_freq_yes                     1611 non-null   bool
#  5   caloric_freq_nan                     1611 non-null   bool
#  6   devices_perday_up to 2               1611 non-null   bool
#  7   devices_perday_up to 5               1611 non-null   bool
#  8   devices_perday_nan                   1611 non-null   bool
#  9   eat_between_meals_Frequently         1611 non-null   bool
#  10  eat_between_meals_Never              1611 non-null   bool
#  11  eat_between_meals_Sometimes          1611 non-null   bool
#  12  eat_between_meals_nan                1611 non-null   bool
#  13  gender_Male                          1611 non-null   bool
#  14  gender_nan                           1611 non-null   bool
#  15  monitor_calories_yes                 1611 non-null   bool
#  16  monitor_calories_nan                 1611 non-null   bool
#  17  parent_overweight_yes                1611 non-null   bool
#  18  parent_overweight_nan                1611 non-null   bool
#  19  physical_activity_perweek_3 to 4     1611 non-null   bool
#  20  physical_activity_perweek_5 or more  1611 non-null   bool
#  21  physical_activity_perweek_nan        1611 non-null   bool
#  22  smoke_yes                            1611 non-null   bool
#  23  smoke_nan                            1611 non-null   bool
#  24  transportation_Car                   1611 non-null   bool
#  25  transportation_Motorbike             1611 non-null   bool
#  26  transportation_Public                1611 non-null   bool
#  27  transportation_Walk                  1611 non-null   bool
#  28  transportation_nan                   1611 non-null   bool
#  29  veggies_freq_Never                   1611 non-null   bool
#  30  veggies_freq_Sometimes               1611 non-null   bool
#  31  veggies_freq_nan                     1611 non-null   bool
#  32  water_daily_less than 1              1611 non-null   bool
#  33  water_daily_more than 2              1611 non-null   bool
#  34  water_daily_nan                      1611 non-null   bool
# dtypes: bool(35)
# memory usage: 55.2 KB
# None
#       alcohol_freq_Frequently  alcohol_freq_Never  alcohol_freq_Sometimes  \
# 0                       False                True                   False
# 1                        True               False                   False
# 2                        True               False                   False
# 3                       False               False                    True
# 4                       False               False                    True
# ...                       ...                 ...                     ...
# 1606                    False               False                    True
# 1607                    False               False                    True
# 1608                    False               False                    True
# 1609                    False               False                    True
# 1610                    False               False                    True
#
#       alcohol_freq_nan  caloric_freq_yes  caloric_freq_nan  \
# 0                False             False             False
# 1                False             False             False
# 2                False             False             False
# 3                False             False             False
# 4                False             False             False
# ...                ...               ...               ...
# 1606             False             False              True
# 1607             False              True             False
# 1608             False              True             False
# 1609             False              True             False
# 1610             False              True             False
#
#       devices_perday_up to 2  devices_perday_up to 5  devices_perday_nan  \
# 0                      False                    True               False
# 1                      False                    True               False
# 2                       True                   False               False
# 3                       True                   False               False
# 4                       True                   False               False
# ...                      ...                     ...                 ...
# 1606                   False                    True               False
# 1607                   False                    True               False
# 1608                   False                    True               False
# 1609                   False                    True               False
# 1610                   False                    True               False
#
#       eat_between_meals_Frequently  ...  transportation_Motorbike  \
# 0                            False  ...                     False
# 1                            False  ...                     False
# 2                            False  ...                     False
# 3                            False  ...                     False
# 4                            False  ...                     False
# ...                            ...  ...                       ...
# 1606                         False  ...                     False
# 1607                         False  ...                     False
# 1608                         False  ...                     False
# 1609                         False  ...                     False
# 1610                         False  ...                     False
#
#       transportation_Public  transportation_Walk  transportation_nan  \
# 0                      True                False               False
# 1                      True                False               False
# 2                     False                 True               False
# 3                      True                False               False
# 4                      True                False               False
# ...                     ...                  ...                 ...
# 1606                   True                False               False
# 1607                  False                False                True
# 1608                   True                False               False
# 1609                   True                False               False
# 1610                   True                False               False
#
#       veggies_freq_Never  veggies_freq_Sometimes  veggies_freq_nan  \
# 0                  False                    True             False
# 1                  False                    True             False
# 2                  False                   False             False
# 3                  False                    True             False
# 4                  False                    True             False
# ...                  ...                     ...               ...
# 1606               False                   False             False
# 1607               False                   False             False
# 1608               False                   False             False
# 1609               False                   False             False
# 1610               False                   False             False
#
#       water_daily_less than 1  water_daily_more than 2  water_daily_nan
# 0                       False                    False            False
# 1                       False                    False            False
# 2                       False                    False            False
# 3                       False                    False            False
# 4                       False                    False            False
# ...                       ...                      ...              ...
# 1606                    False                    False            False
# 1607                    False                    False            False
# 1608                    False                    False            False
# 1609                    False                     True            False
# 1610                    False                     True            False
#
# [1611 rows x 35 columns]

# %%
knn_imputer = KNNImputer(n_neighbors=5)
columns_to_impute = ['caloric_freq_nan']  # Specify the columns you want to impute
x[columns_to_impute] = knn_imputer.fit_transform(x[columns_to_impute])
x
